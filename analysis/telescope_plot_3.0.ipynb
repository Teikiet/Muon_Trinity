# %%
from read_telescope import VAtmosAbsorption, extract_data_from_file, filter_photons, simulate_davies_cotton_optics, read_particle_file, convert_coordinates_to_shower
from camera_response import noise_function, camera_response_function
import numpy as np
import random
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import poisson, norm

def make_2d_histogram_consistent(x, y, x_edges, y_edges):
    """
    Create 2D histogram with consistent bin edges
    """
    if len(x) == 0 or len(y) == 0:
        # Return empty histogram with correct shape
        return np.zeros((len(y_edges)-1, len(x_edges)-1))
    
    heatmap, _, _ = np.histogram2d(x, y, bins=[x_edges, y_edges])
    return heatmap.T  # Transpose to match the orientation of the data

def Camera_Response(T_photon, x_base, y_base, w, noise=True):
    if len(T_photon) > 0:
        T_photon = T_photon - T_photon.min()  # Normalize time to start at zero
        delta_t = 10 # ns
        N = int(T_photon.max() / delta_t) + 1
        t_min = 0
        t_max = T_photon.max()
        n_window = int(np.ceil((t_max - t_min) / delta_t))
        # Pre-allocate lists
        T = [] # List to store time windows
        X = [] # List to store x coordinates
        Y = [] # List to store y coordinates
        W = [] # List to store wavelengths

        # Use numpy's digitize for efficient binning
        time_edges = np.arange(t_min, t_max + delta_t, delta_t)
        bin_indices = np.digitize(T_photon, time_edges) - 1

        # Group data by time windows
        for i in range(n_window):
            mask = (bin_indices == i)
            T.append(T_photon[mask])
            X.append(x_base[mask])
            Y.append(y_base[mask])
            W.append(w[mask])
            # Define global bin edges
        n_bins = 16
        r_cam = 6
        x_min, x_max = -r_cam, r_cam
        y_min, y_max =  -r_cam, r_cam
        # Add small padding to avoid edge effects
        x_padding = (x_max - x_min) * 0.01
        y_padding = (y_max - y_min) * 0.01

        # Create consistent bin edges for all histograms
        global_x_edges = np.linspace(x_min - x_padding, x_max + x_padding, n_bins + 1)
        global_y_edges = np.linspace(y_min - y_padding, y_max + y_padding, n_bins + 1)

        H = [] # List to store histograms
        Times = [] # List to store corresponding times
        center_times = time_edges[1:] - delta_t/2  # Fixed: should be delta_t/2, not 5
        for i in range(len(X)):
            h2d = make_2d_histogram_consistent(X[i], Y[i], global_x_edges, global_y_edges)
            # Apply your Trigger condition
            if (h2d >= 1).any(): #At least one bin must have a count >= 1
                H.append(h2d)
                Times.append(center_times[i])
        if len(H) > 0: 
            # Convert to numpy arrays for easier manipulation
            H = np.array(H) 
            if noise == True:
                Noise = noise_function(H, lambda_fit=0.74)  # Generate noise for the histograms
                H += Noise  # Add noise to the histograms
            else:
                Noise = None
            Times = np.array(Times)
            # Camera response function to weight the histograms
            h = H.copy()
            for i in range(len(Times)):
                weight = camera_response_function(np.array(Times), Times[i])
                h += weight[:, np.newaxis, np.newaxis] * H[i]
            return h, H, Times, Noise #H is no camera response, h is with camera response
        else:
            print("No histograms created. Check your data and filter conditions.")
            return None, None, None, None
    else:
        print("No photons found in the data.")
        return None, None, None, None

def Monte_Carlos_Avg(zenith, production_height="20.E5", gen_radi = "1500", noise=True, E_mag = 6, particle = 6, N = 10):
    # Define the parameters
    #zenith = 88  #  available: 0 30 60 88 degrees
      # available: 1.00E6, 1.00E5, 1.00E4, 1.00E3, 1.00E1 GeV
      # 5 is mu+, 6 is mu-
    #production_height = "20.E5"  # available: 10.E5 20.E5 cm
      # telescope radius in cm, available:  1500 cm
    Store_Events = []  # Store the results of each Monte Carlo iteration
    for i in range(N):
        id = random.randint(1, 50)  # Randomly select an ID for each iteration
        ID = [id]
        input_files = [
            f"/uufs/chpc.utah.edu/common/home/u1520754/corsika_results/notch_h{production_height}_r{gen_radi}._Trinity/out_sib23d-pId{particle}-En1.00E{E_mag}-{zenith}./OUTPUT_1.00E{E_mag}_{particle}_{zenith}._{100+i}/telescope.dat"
            for i in ID
        ]
        atmabs_file="/uufs/chpc.utah.edu/common/home/u1520754/corsika-78010/run/atmabs.dat"
        ran_val = random.randint(0, 10000)  # Random seed for reproducibility
        atmos = VAtmosAbsorption(model="CORSIKA", seed=ran_val, source_file=atmabs_file)
        T_photon, x_base, y_base, w, Zem, cos_x, cos_y = extract_data_from_file(input_files, atmos, R=float(gen_radi), filter=False, optics=False)
        #off set the x and y positions of the shower to the center of the camera randomly
        x_base = x_base - np.random.uniform(-150, 150)  # Randomly offset x position
        y_base = y_base - np.random.uniform(-150, 150)  # Randomly offset y position
        # Apply the Davies-Cotton optics simulation
        x_base, y_base, w, Zem, T_photon, incident_angles, cos_x, cos_y = simulate_davies_cotton_optics(
                    x_base, y_base, w, Zem, T_photon, cos_x, cos_y, zenith,
                    R=150, r_cam=6, 
                    get_mirror_photons=False,
                    plotting=False
                )
        #Apply the atmospheric absorption and photon detection efficiency:
        zenith_rad = np.radians(zenith)
        atmabs_file="/uufs/chpc.utah.edu/common/home/u1520754/corsika-78010/run/atmabs.dat"
        ran_val = random.randint(0, 10000)  # Random seed for reproducibility
        atmos = VAtmosAbsorption(model="CORSIKA", seed=ran_val, source_file=atmabs_file)
        x_base, y_base, T_photon, w, Zem, mask = filter_photons(x_base, y_base, T_photon, w, Zem, zenith_rad, atmos, filter=True)
        T_photon = np.array(T_photon)
        # Call the camera response function
        h, _, _, _ = Camera_Response(T_photon, x_base, y_base, w, noise=noise)
        Trigger_events = sum(h[np.where(h>=20)]) if h is not None else 0
        Store_Events.append(Trigger_events)  # Store the number of triggered events for this iteration
    return Store_Events

def calculate_detection_efficiency(pe_counts, threshold=20, alpha=0.05, n_bootstrap=10000):
    """
    Calculates Poisson-based detection efficiency and its uncertainty via:
      1. Delta-method (analytic)
      2. Bootstrap resampling

    Parameters:
    - pe_counts: list or array of observed PE counts
    - threshold: integer threshold for detection (default=20)
    - alpha: significance level for CI (default=0.05 for 95% CI)
    - n_bootstrap: number of bootstrap samples (default=10000)

    Returns:
    - lambda_hat: estimated mean PE count
    - p_det: detection efficiency P(N>=threshold | lambda_hat)
    - ci_delta: (lower, upper) CI via delta method
    - ci_bootstrap: (lower, upper) CI via bootstrap
    """
    pe = np.array(pe_counts)
    N = len(pe)
    lambda_hat = pe.mean()

    # Poisson-based detection probability
    p_det = 1 - poisson.cdf(threshold - 1, lambda_hat)

    # Bootstrap CI
    rng = np.random.default_rng()
    p_boot = []
    for _ in range(n_bootstrap):
        sample = rng.choice(pe, size=N, replace=True)
        lambda_b = sample.mean()
        p_b = 1 - poisson.cdf(threshold - 1, lambda_b)
        p_boot.append(p_b)
    lower = p_det - np.percentile(p_boot, 100 * alpha/2)
    upper = np.percentile(p_boot, 100 * (1 - alpha/2)) - p_det
    ci_bootstrap = (lower, upper)

    return lambda_hat, p_det, ci_bootstrap

# %%
from eventio import IACTFile
import numpy as np
from read_telescope import VAtmosAbsorption, extract_data_from_file, filter_photons, simulate_davies_cotton_optics, read_particle_file, convert_coordinates_to_shower
from camera_response import noise_function, camera_response_function
import random
import matplotlib.pyplot as plt
from scipy.stats import poisson, norm

def get_where_muon_landed(id, gen_radi = "1500", particle = 6, zenith_tele = 91, azimuth_tele = 280):
    file_path = f"/uufs/chpc.utah.edu/common/home/u1520754/corsika_results/notch_r{gen_radi}.0_Trinity_MC_E3/out_sib23d-pId{particle}/OUTPUT_{1000+id}/DAT00{1000+id}"

    particle_list = [5, 6]  # List of particles to read

    PP = read_particle_file(file_path, particle_list)
    #id, x, y,t, E, direction_vector = pp[0], pp[4], pp[5], pp[6], pp[7]
    P_id = [pp[0] for pp in PP]
    x = [pp[1] for pp in PP]
    y = [pp[2] for pp in PP]
    t = [pp[3] for pp in PP]
    E = [pp[4] for pp in PP]
    E_all = E
    direction_vector = [pp[5] for pp in PP]
    cos_x = [pp[5][0] for pp in PP]
    cos_y = [pp[5][1] for pp in PP]
    tele_radi_temp = float(gen_radi)
    zenith_rad = np.radians(zenith_tele)
    azimuth_rad = np.radians(azimuth_tele)  # Assuming azimuth angle is 0 for simplicity
    x = np.array(x) #-  tele_radi_temp * np.tan(zenith_rad)*np.cos(azimuth_rad) 
    y = np.array(y) #- tele_radi_temp * np.tan(zenith_rad)*np.sin(azimuth_rad)
    cos_x = np.array(cos_x)
    cos_y = np.array(cos_y)
    #file = f"/uufs/chpc.utah.edu/common/home/u1520754/corsika_results/notch_r{gen_radi}.0_Trinity_MC_E3/out_sib23d-pId{particle}/OUTPUT_{1000+id}/telescope.dat"
    """with IACTFile(file) as streamer:
        events = iter(streamer)
        event = next(events)
        telescope_position0 = streamer.telescope_positions[0]
        #telescope_position1 = streamer.telescope_positions[1]
    x = x - telescope_position0[0]#(telescope_position1[0]-telescope_position0[0])  # Offset x position by telescope position
    y = y - telescope_position0[1]#(telescope_position1[1]-telescope_position0[1])  # Offset y position by telescope position"""
    x, y, cos_x, cos_y = convert_coordinates_to_shower(x, y, cos_x, cos_y, azimuth_rad=np.radians(-azimuth_tele), zenith_deg=zenith_tele)
    try:
        mask = np.where(E==max(E)) 
        x = x[mask]
        y = y[mask]
        cos_x = cos_x[mask]
        cos_y = cos_y[mask]
        E_max = np.array(E)[mask]
        t = np.array(t)[mask]
        cos_z = np.sqrt(1 - cos_x**2 - cos_y**2)  # Calculate cos(z) from cos(x) and cos(y)
        phi = np.arctan2(cos_y, cos_x)  # Calculate azimuth angle
        phi_deg = np.degrees(phi)  # Convert azimuth angle to degrees
        theta_z_deg = np.degrees(np.arccos(cos_z))
        return x,y,theta_z_deg, E_max,t, phi_deg, E_all
    except ValueError:
        return None, None, None, None, None, None, None


x_data = []
y_data = []
z_data = []
Energy_data = []
id = range(0, 564)
X = []
Y = []
Z_deg = []
Phi_deg = []
ID_valid = []
for i in id: 
    try:      
        x, y, theta_z_deg, E_max, t, phi_deg, E_all = get_where_muon_landed(i, gen_radi="1500", particle=6)
        x = float(x)
        y = float(y)
        theta_z_deg = float(theta_z_deg)
        phi_deg = float(phi_deg)
        X.append(x)
        Y.append(y)
        Z_deg.append(theta_z_deg)
        Phi_deg.append(phi_deg)
        ID_valid.append(i)
        Energy_data = np.concatenate((Energy_data, E_max), axis=0)  # Concatenate energy data
    except TypeError:
        print(f"TypeError encountered for ID {i}. Skipping this ID.")
        continue
Energy_data = np.array(Energy_data)
X = np.array(X)
Y = np.array(Y)
ID_valid = np.array(ID_valid)
Z_deg = np.array(Z_deg)
Phi_deg = np.array(Phi_deg)
X_mean = np.mean(X)
Y_mean = np.mean(Y)
Z_deg_mean = np.mean(Z_deg)
Phi_deg_mean = np.mean(Phi_deg)
X_std = np.std(X)
Y_std = np.std(Y)
Z_deg_std = np.std(Z_deg)
Phi_deg_std = np.std(Phi_deg)
x_data.append((X_mean, X_std))
y_data.append((Y_mean, Y_std))
z_data.append((Z_deg_mean, Z_deg_std))
print(f"Mean X: {X_mean:.2f} cm, Std X: {X_std:.2f} cm, Mean Y: {Y_mean:.2f} cm, Std Y: {Y_std:.2f} cm, Mean Z: {Z_deg_mean:.2f}°, Std Z: {Z_deg_std:.2f}°, Mean Phi: {Phi_deg_mean:.2f}°, Std Phi: {Phi_deg_std:.2f}° ")
# Out:
# /tmp/ipykernel_2492529/4138214109.py:71: DeprecationWarning:
#
# Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#
# /tmp/ipykernel_2492529/4138214109.py:72: DeprecationWarning:
#
# Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#
# /tmp/ipykernel_2492529/4138214109.py:73: DeprecationWarning:
#
# Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#
# /tmp/ipykernel_2492529/4138214109.py:74: DeprecationWarning:
#
# Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
# TypeError encountered for ID 41. Skipping this ID.
# TypeError encountered for ID 46. Skipping this ID.
# TypeError encountered for ID 57. Skipping this ID.
# TypeError encountered for ID 78. Skipping this ID.
# TypeError encountered for ID 87. Skipping this ID.
# TypeError encountered for ID 105. Skipping this ID.
# TypeError encountered for ID 112. Skipping this ID.
# TypeError encountered for ID 130. Skipping this ID.
# TypeError encountered for ID 178. Skipping this ID.
# TypeError encountered for ID 192. Skipping this ID.
# TypeError encountered for ID 196. Skipping this ID.
# TypeError encountered for ID 209. Skipping this ID.
# TypeError encountered for ID 279. Skipping this ID.
# TypeError encountered for ID 295. Skipping this ID.
# TypeError encountered for ID 296. Skipping this ID.
# TypeError encountered for ID 364. Skipping this ID.
# TypeError encountered for ID 477. Skipping this ID.
# TypeError encountered for ID 479. Skipping this ID.
# TypeError encountered for ID 488. Skipping this ID.
# TypeError encountered for ID 500. Skipping this ID.
# TypeError encountered for ID 552. Skipping this ID.
# Mean X: -9812.45 cm, Std X: 31140.22 cm, Mean Y: -22276.99 cm, Std Y: 56683.06 cm, Mean Z: 14.95°, Std Z: 6.60°, Mean Phi: -17.73°, Std Phi: 125.14°

# %%
#log scale color bar
mask = np.where((X**2 + Y**2 < 1500**2)&(Energy_data>1e2)&(Z_deg<10))  # Mask for points within a circle of radius 15    
import matplotlib.colors as mcolors
plt.scatter(X[mask]/1e2, Y[mask]/1e2, c = Z_deg[mask], cmap='viridis', s=50)#, norm=mcolors.LogNorm())
#plt.xlim(-15, 15)
#plt.ylim(-15, 15)
plt.colorbar(label='Incident Angle (degrees)')
plt.xlabel(' X Position (m)')
plt.ylabel(' Y Position (m)')
plt.title('Mean Position of Muons')
plt.grid()
plt.show()
print(ID_valid[mask])
# Out:
# [ 17  22  39  47  53  55  83  86  94 128 129 138 186 197 200 207 218 249
#  270 274 303 332 334 363 366 373 385 398 420 440 450 456 464 489 505 523
#  524 525 553]

# %%
def get_parameters(filename, line_number):
    """
    Get E, h, z from a specific line number (1-based, excluding header)
    """
    with open(filename, 'r') as file:
        lines = file.readlines()
    
    # Skip header (line 0) and get the requested line
    data_line_index = line_number  # line_number is already 1-based for data
    
    if data_line_index >= len(lines):
        raise IndexError(f"Line {line_number} not found. File has {len(lines)-1} data lines.")
    
    # Parse the line
    line = lines[data_line_index].strip()
    energy, height, zenith = line.split()
    
    return float(energy), float(height), float(zenith)

# Usage
filename = "/uufs/chpc.utah.edu/common/home/u1520754/corsika_inputs/sampled_muon_parameters.txt"
H = []
Z = []
A = []
for i in ID_valid[mask]+1:
    E, h, z = get_parameters(filename, i)
    gen_radi = 1500  # Example value, adjust as needed
    particle = 6  # Example value, adjust as needed
    id = i-1
    input_files =  f"/uufs/chpc.utah.edu/common/home/u1520754/corsika_results/notch_r{gen_radi}.0_Trinity_MC_E3/out_sib23d-pId{particle}/OUTPUT_{1000+id}/telescope.dat"
    T_photon, x_base, y_base, w, Zem, cos_x, cos_y, azimuth_event_degree, zenith_event_degree = extract_data_from_file(input_files, atmos, R=float(gen_radi), 
                                                                        tele_id=0,
                                                                        filter=False, 
                                                                        optics=False, 
                                                                        shower_coordinates=False,
                                                                        use_brightness_pixel=False,
                                                                        zenith_tele=0, azimuth_tele=0
                                                                        )
    #print(f"Line {i}: E={E} GeV, h={h/1e5} km, zenith={z}°, azimuth={360+azimuth_event_degree}°")
    H.append(h)
    Z.append(z)
    A.append(360+azimuth_event_degree)

# %%
plt.scatter(A, Z, c=H, alpha=0.5, s=50, cmap='viridis', norm=mcolors.LogNorm())
plt.colorbar(label='Height (m)')
plt.xlabel('Azimuth (degrees)')
plt.ylabel('Zenith (degrees)')
plt.title('Zenith vs Azimuth of Muons')
plt.grid()
plt.show()

# %%
energy_bins = np.logspace(np.log10(np.min(Energy_data)), np.log10(np.max(Energy_data)), 50)
plt.hist(Energy_data, bins=energy_bins, alpha=0.7, label='Energy Distribution')
plt.yscale('log')  # Set y-axis to logarithmic scale for better visibility
plt.xscale('log')  # Set x-axis to logarithmic scale for better visibility
plt.xlabel('Energy (GeV)')
plt.ylabel('Frequency')
plt.title('Energy Distribution of Muons')
plt.legend()
plt.grid(True)
plt.show()

# %%
from eventio import IACTFile
import numpy as np
from read_telescope import VAtmosAbsorption, extract_data_from_file, filter_photons, simulate_davies_cotton_optics, read_particle_file, convert_coordinates_to_shower
from camera_response import noise_function, camera_response_function
import random
import matplotlib.pyplot as plt
from scipy.stats import poisson, norm
from matplotlib import colors as mcolors
def get_where_muon_landed(id, gen_radi = "1500", particle = 6, zenith_tele = 91, azimuth_tele = 280):
    file_path = f"/uufs/chpc.utah.edu/common/home/u1520754/corsika_results/notch_r{gen_radi}.0_Trinity_MC_E3/out_sib23d-pId{particle}/OUTPUT_{1000+id}/DAT00{1000+id}"

    particle_list = [1,2,3,4,5, 6]  # List of particles to read

    PP = read_particle_file(file_path, particle_list)
    #id, x, y,t, E, direction_vector = pp[0], pp[4], pp[5], pp[6], pp[7]
    P_id = [pp[0] for pp in PP]
    x = [pp[1] for pp in PP]
    y = [pp[2] for pp in PP]
    t = [pp[3] for pp in PP]
    E = [pp[4] for pp in PP]
    E_all = E
    direction_vector = [pp[5] for pp in PP]
    cos_x = [pp[5][0] for pp in PP]
    cos_y = [pp[5][1] for pp in PP]
    tele_radi_temp = float(gen_radi)
    zenith_rad = np.radians(zenith_tele)
    azimuth_rad = np.radians(azimuth_tele)  # Assuming azimuth angle is 0 for simplicity
    x = np.array(x) #-  tele_radi_temp * np.tan(zenith_rad)*np.cos(azimuth_rad) 
    y = np.array(y) #- tele_radi_temp * np.tan(zenith_rad)*np.sin(azimuth_rad)
    cos_x = np.array(cos_x)
    cos_y = np.array(cos_y)
    #file = f"/uufs/chpc.utah.edu/common/home/u1520754/corsika_results/notch_r{gen_radi}.0_Trinity_MC_E3/out_sib23d-pId{particle}/OUTPUT_{1000+id}/telescope.dat"
    """with IACTFile(file) as streamer:
        events = iter(streamer)
        event = next(events)
        telescope_position0 = streamer.telescope_positions[0]
        #telescope_position1 = streamer.telescope_positions[1]
    x = x - telescope_position0[0]#(telescope_position1[0]-telescope_position0[0])  # Offset x position by telescope position
    y = y - telescope_position0[1]#(telescope_position1[1]-telescope_position0[1])  # Offset y position by telescope position"""
    x, y, cos_x, cos_y = convert_coordinates_to_shower(x, y, cos_x, cos_y, azimuth_rad=np.radians(-azimuth_tele), zenith_deg=zenith_tele)
    try:
        mask = np.where(E==max(E)) 
        x = x[mask]
        y = y[mask]
        cos_x = cos_x[mask]
        cos_y = cos_y[mask]
        E_max = np.array(E)[mask]
        t = np.array(t)[mask]
        cos_z = np.sqrt(1 - cos_x**2 - cos_y**2)  # Calculate cos(z) from cos(x) and cos(y)
        phi = np.arctan2(cos_y, cos_x)  # Calculate azimuth angle
        phi_deg = np.degrees(phi)  # Convert azimuth angle to degrees
        theta_z_deg = np.degrees(np.arccos(cos_z))
        return x,y,theta_z_deg, E_max,t, phi_deg, E_all
    except ValueError:
        return None, None, None, None, None, None, None

id = 17
ID = [id]
# Define the parameters
particle = 6  # 5 is mu+, 6 is mu-
gen_radi = "1500"  # telescope radius in cm, available:  1500 cm
input_files =  f"/uufs/chpc.utah.edu/common/home/u1520754/corsika_results/notch_r{gen_radi}.0_Trinity_MC_E3/out_sib23d-pId{particle}/OUTPUT_{1000+id}/telescope.dat"
atmabs_file="/uufs/chpc.utah.edu/common/home/u1520754/corsika-78010/run/atmabs.dat"
ran_val = random.randint(0, 10000)  # Random seed for reproducibility_3
atmos = VAtmosAbsorption(model="CORSIKA", seed=ran_val, source_file=atmabs_file)
# Extract data from the files
zenith = 91
azimuth = 280
T_photon, x_base, y_base, w, Zem, cos_x, cos_y, azimuth_event_degree, zenith_event_degree = extract_data_from_file(input_files, atmos, R=float(gen_radi), 
                                                                        tele_id=0,
                                                                        filter=False, 
                                                                        optics=True, 
                                                                        shower_coordinates=True,
                                                                        use_brightness_pixel=True,
                                                                        zenith_tele=zenith, azimuth_tele=azimuth
                                                                        )
try:
    x_muon, y_muon, theta_z_deg, E, t, phi_deg, E_all = get_where_muon_landed(ID[0], gen_radi = gen_radi,
                                                                            particle = particle,
                                                                            zenith_tele = zenith,
                                                                            azimuth_tele = azimuth)
    print(x_muon/100, y_muon/100)
    plt.plot(x_muon/100, y_muon/100, 's', c='red', markersize=10, label=f'Muon Position with Energy {E} GeV')
except TypeError:
    pass
cos_z = np.sqrt(1 - cos_x**2 - cos_y**2)  # Calculate cos(z) from cos(x) and cos(y)
incident_angle = np.degrees(np.arccos(cos_z))  # Convert zenith angle to degrees
azimuth_event = np.degrees(np.arctan2(cos_y, cos_x))  # Calculate azimuth angle
print(np.mean(incident_angle), np.std(incident_angle), np.mean(azimuth_event), np.std(azimuth_event))
gen_radi = max([max(abs(x_base)), max(abs(y_base))])*1.2  # Get the maximum radius from the photon positions
Production_height = Zem/100
plt.scatter(x_base/100, y_base/100, c=Production_height, alpha=0.5, s=50, cmap='viridis', norm=mcolors.LogNorm())
print("Number of valid photons:", len(x_base))
print("Energy",E)
plt.colorbar(label='Production Height (m)')
plt.ylabel('y (m)')
plt.xlabel('x (m)')
plt.xlim(-float(gen_radi)/100, float(gen_radi)/100)
plt.ylim(-float(gen_radi)/100, float(gen_radi)/100)
plt.title(f'Photon Distribution')
plt.legend()
plt.show()
print(azimuth_event_degree+360, zenith_event_degree)
plt.hist2d(azimuth_event, incident_angle, bins=50, cmap='viridis', norm=mcolors.LogNorm())
plt.colorbar(label='Counts')
plt.xlabel('Azimuth Angle (degrees)')
plt.ylabel('Incident Angle (degrees)')
plt.show()
# Out:
# Atmospheric extinction model: CORSIKA
# VAtmosAbsorption: reading atmospheric extinction file (from CORSIKA): /uufs/chpc.utah.edu/common/home/u1520754/corsika-78010/run/atmabs.dat
# Brightness pixel location in cm: (210.00, -450.00) with value 1187.00
# Brightness pixel location in cm: (-15.00, 3.00) with value 120.00
# Number of photons in event after optics only: 15 of 31924 Ratio: 0.00046986593158752037
# [1.95018181] [-4.49931224]
# 8.92728596127052 1.1596853851073856 157.43465673988138 1.1793231531038617
# Number of valid photons: 15
# Energy [2806.6748]
# 283.40002 82.82828

# %%
from read_telescope import VAtmosAbsorption, extract_data_from_file, filter_photons, simulate_davies_cotton_optics, read_particle_file, convert_coordinates_to_shower
from camera_response import noise_function, camera_response_function
import numpy as np
import random
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import poisson, norm
from eventio import IACTFile

File_Size = []
ID_data = range(120, 140)  # IDs to iterate over
error_id = []
for id in ID_data:
    ID = [id]
    # Define the parameters
    zenith = 88  #  available: 0 30 60 88 degrees
    E_mag = 6  # available: 1.00E6, 1.00E5, 1.00E4, 1.00E3, 1.00E1 GeV
    particle = 6  # 5 is mu+, 6 is mu-
    production_height = "20.E5"  # available: 10.E5 20.E5 cm
    gen_radi = "1500"  # telescope radius in cm, available:  1500 cm
    input_files = [
            f"/uufs/chpc.utah.edu/common/home/u1520754/corsika_results/notch_r{gen_radi}.0_Trinity_MC_E3/out_sib23d-pId{particle}/OUTPUT_{1000+i}/telescope.dat"
            for i in ID
        ]
    file = input_files[0]
    #check file size:
    import os
    file_size = os.path.getsize(file)
    File_Size.append(file_size)
    try:
        with IACTFile(file) as streamer:
            print(streamer)
            events = iter(streamer)
            event = next(events)
            #print(streamer.telescope_positions[0])
    except Exception as e:
        print(f"Error processing ID {id}: {e}")
        error_id.append(id)
print(f"Error IDs: {error_id}")
plt.figure(figsize=(10, 6))
plt.plot(ID_data, File_Size, marker='o', linestyle='-', color='b')
plt.title('File Size vs ID')
plt.xlabel('ID')
plt.ylabel('File Size (bytes)')
plt.xticks(ID_data)  # Set x-ticks to match IDs
plt.grid()
plt.show()
#250, 253, 255, 476, 478, 479, 482, 483, 484, 486, 487, 490, 520, 521, 522, 523
# Out:
# IACTFile(
#   path=/uufs/chpc.utah.edu/common/home/u1520754/corsika_results/notch_r1500.0_Trinity_MC_E3/out_sib23d-pId6/OUTPUT_1120/telescope.dat
#   n_telescopes=2
# )
# IACTFile(
#   path=/uufs/chpc.utah.edu/common/home/u1520754/corsika_results/notch_r1500.0_Trinity_MC_E3/out_sib23d-pId6/OUTPUT_1121/telescope.dat
#   n_telescopes=2
# )
# IACTFile(
#   path=/uufs/chpc.utah.edu/common/home/u1520754/corsika_results/notch_r1500.0_Trinity_MC_E3/out_sib23d-pId6/OUTPUT_1122/telescope.dat
#   n_telescopes=2
# )
# IACTFile(
#   path=/uufs/chpc.utah.edu/common/home/u1520754/corsika_results/notch_r1500.0_Trinity_MC_E3/out_sib23d-pId6/OUTPUT_1123/telescope.dat
#   n_telescopes=2
# )
# IACTFile(
#   path=/uufs/chpc.utah.edu/common/home/u1520754/corsika_results/notch_r1500.0_Trinity_MC_E3/out_sib23d-pId6/OUTPUT_1124/telescope.dat
#   n_telescopes=2
# )
# IACTFile(
#   path=/uufs/chpc.utah.edu/common/home/u1520754/corsika_results/notch_r1500.0_Trinity_MC_E3/out_sib23d-pId6/OUTPUT_1125/telescope.dat
#   n_telescopes=2
# )
# IACTFile(
#   path=/uufs/chpc.utah.edu/common/home/u1520754/corsika_results/notch_r1500.0_Trinity_MC_E3/out_sib23d-pId6/OUTPUT_1126/telescope.dat
#   n_telescopes=2
# )
# IACTFile(
#   path=/uufs/chpc.utah.edu/common/home/u1520754/corsika_results/notch_r1500.0_Trinity_MC_E3/out_sib23d-pId6/OUTPUT_1127/telescope.dat
#   n_telescopes=2
# )
# IACTFile(
#   path=/uufs/chpc.utah.edu/common/home/u1520754/corsika_results/notch_r1500.0_Trinity_MC_E3/out_sib23d-pId6/OUTPUT_1128/telescope.dat
#   n_telescopes=2
# )
# IACTFile(
#   path=/uufs/chpc.utah.edu/common/home/u1520754/corsika_results/notch_r1500.0_Trinity_MC_E3/out_sib23d-pId6/OUTPUT_1129/telescope.dat
#   n_telescopes=2
# )
# IACTFile(
#   path=/uufs/chpc.utah.edu/common/home/u1520754/corsika_results/notch_r1500.0_Trinity_MC_E3/out_sib23d-pId6/OUTPUT_1130/telescope.dat
#   n_telescopes=2
# )
# IACTFile(
#   path=/uufs/chpc.utah.edu/common/home/u1520754/corsika_results/notch_r1500.0_Trinity_MC_E3/out_sib23d-pId6/OUTPUT_1131/telescope.dat
#   n_telescopes=2
# )
# IACTFile(
#   path=/uufs/chpc.utah.edu/common/home/u1520754/corsika_results/notch_r1500.0_Trinity_MC_E3/out_sib23d-pId6/OUTPUT_1132/telescope.dat
#   n_telescopes=2
# )
# IACTFile(
#   path=/uufs/chpc.utah.edu/common/home/u1520754/corsika_results/notch_r1500.0_Trinity_MC_E3/out_sib23d-pId6/OUTPUT_1133/telescope.dat
#   n_telescopes=2
# )
# IACTFile(
#   path=/uufs/chpc.utah.edu/common/home/u1520754/corsika_results/notch_r1500.0_Trinity_MC_E3/out_sib23d-pId6/OUTPUT_1134/telescope.dat
#   n_telescopes=2
# )
# IACTFile(
#   path=/uufs/chpc.utah.edu/common/home/u1520754/corsika_results/notch_r1500.0_Trinity_MC_E3/out_sib23d-pId6/OUTPUT_1135/telescope.dat
#   n_telescopes=2
# )
# IACTFile(
#   path=/uufs/chpc.utah.edu/common/home/u1520754/corsika_results/notch_r1500.0_Trinity_MC_E3/out_sib23d-pId6/OUTPUT_1136/telescope.dat
#   n_telescopes=2
# )
# IACTFile(
#   path=/uufs/chpc.utah.edu/common/home/u1520754/corsika_results/notch_r1500.0_Trinity_MC_E3/out_sib23d-pId6/OUTPUT_1137/telescope.dat
#   n_telescopes=2
# )
# IACTFile(
#   path=/uufs/chpc.utah.edu/common/home/u1520754/corsika_results/notch_r1500.0_Trinity_MC_E3/out_sib23d-pId6/OUTPUT_1138/telescope.dat
#   n_telescopes=2
# )
# IACTFile(
#   path=/uufs/chpc.utah.edu/common/home/u1520754/corsika_results/notch_r1500.0_Trinity_MC_E3/out_sib23d-pId6/OUTPUT_1139/telescope.dat
#   n_telescopes=2
# )
# Error IDs: []

# %%
Pro_Height = [ "10.E5"] #"5.E5", "10.E5", "15.E5", "20.E5", "25.E5","30.E5"
zenith = [88]  # Zenith angles in degrees
Events_Data = [] 
E_mag = 3 # available: 1.00E6, 1.00E5, 1.00E4, 1.00E3, 1.00E1 GeV
particle = 6 #particle id 
gen_radi = "15000" #cm
for z in zenith:
    Num_triggered_events = []
    for height in Pro_Height:
        Data_id = Monte_Carlos_Avg(z, production_height=height, gen_radi=gen_radi, noise=True, E_mag=E_mag, particle=particle, N=2)
        Data_id = np.array(Data_id)
        height_float = float(height.replace("E", "e")) / 1e5 # Convert to km
        Num_triggered_events.append((height_float, Data_id))
    Events_Data.append((z, Num_triggered_events))
# Out:
# Atmospheric extinction model: CORSIKA
# VAtmosAbsorption: reading atmospheric extinction file (from CORSIKA): /uufs/chpc.utah.edu/common/home/u1520754/corsika-78010/run/atmabs.dat
# Number of photons in event 0: 73005
# Brightness pixel location in cm: (3150.00, 8250.00) with value 1097.00
# Brightness pixel location in cm: (135.00, 45.00) with value 86.00
# Brightness pixel location in cm: (-4.50, -1.50) with value 5.00
# Total shift in cm: (3280.50, 8293.50)
# Atmospheric extinction model: CORSIKA
# VAtmosAbsorption: reading atmospheric extinction file (from CORSIKA): /uufs/chpc.utah.edu/common/home/u1520754/corsika-78010/run/atmabs.dat
# Number of photons: 168
# Number of photons after filtering: 46
# Atmospheric extinction model: CORSIKA
# VAtmosAbsorption: reading atmospheric extinction file (from CORSIKA): /uufs/chpc.utah.edu/common/home/u1520754/corsika-78010/run/atmabs.dat
# Number of photons in event 0: 75251
# Brightness pixel location in cm: (1950.00, 5850.00) with value 1090.00
# Brightness pixel location in cm: (105.00, -45.00) with value 92.00
# Brightness pixel location in cm: (16.50, -7.50) with value 5.00
# Total shift in cm: (2071.50, 5797.50)
# Atmospheric extinction model: CORSIKA
# VAtmosAbsorption: reading atmospheric extinction file (from CORSIKA): /uufs/chpc.utah.edu/common/home/u1520754/corsika-78010/run/atmabs.dat
# Number of photons: 430
# Number of photons after filtering: 110

# %%
#Store Events Data to pickle file
import pickle
with open(f'Events_Data_1E{E_mag}_pid{particle}_88.pickle', 'wb') as f:
    pickle.dump(Events_Data, f)

# %%
#Read pickle file
E_mag = 4
particle = 6
with open(f'Events_Data_1E{E_mag}_pid{particle}_88.pickle', 'rb') as f:
    Events_Data2 = pickle.load(f)
x = list(Events_Data2) # Convert to list for easier manipulation
x = np.array(x, dtype=object)  # Convert to numpy array for easier manipulation
zenith_angles = x[:, 0]  # Extract zenith angles
Pro_Height_float = [np.array([i[0] for i in x[1]]) for x in x]  # Extract production heights in km
Num_triggered_events = [([i[1] for i in x[1]]) for x in x]  # Extract number of events per production height
import numpy as np
from scipy.stats import binom, poisson

# Example list of PE counts for 10 events
def calculate_pe_statistics(pe_counts):
    pe_counts = np.array(pe_counts)
    threshold = 20
    N = len(pe_counts)
    k = sum(np.array(pe_counts) >= threshold)
    p_hat = k / N

    # Binomial (Clopper-Pearson) 95% confidence interval
    alpha = 0.05
    ci_low, ci_high = binom.interval(1 - alpha, N, p_hat, loc=0)
    ci_low /= N
    ci_high /= N

    # Poisson modeling of PE counts
    lambda_hat = np.mean(pe_counts)
    p_det_poisson = 1 - poisson.cdf(threshold - 1, lambda_hat)
    return p_det_poisson

# Example usage:
pe_counts = Num_triggered_events[0][6]
plt.hist(pe_counts, bins=50, density=True, alpha=0.6, color='g', label='PE Counts Distribution')
plt.yscale('log')
print(len(pe_counts))
# Out:
# 5000

# %%
def detect_prob(pe_counts, j):
    pe = pe_counts[0][j]

    # Poisson-based detection probability
    p_det = len(pe[np.where(pe >= 20)])/len(pe)
    # Bootstrap CI
    rng = np.random.default_rng()
    p_boot = []
    n_bootstrap = 10000
    threshold = 20
    N = len(pe)
    alpha = 0.05
    for _ in range(n_bootstrap):
        sample = rng.choice(pe, size=N, replace=True)
        p_b = len(sample[np.where(sample >= threshold)])/len(sample)
        p_boot.append(p_b)
    lower = p_det - np.percentile(p_boot, 100 * alpha/2)
    upper = np.percentile(p_boot, 100 * (1 - alpha/2)) - p_det
    ci_bootstrap = (lower, upper)
    return p_det, ci_bootstrap
plt.figure(figsize=(10, 6))
x_data = []
y_data = []
y_err = []
x = list(Events_Data) # Convert to list for easier manipulation
x = np.array(x, dtype=object)  # Convert to numpy array for easier manipulation
zenith_angles = x[:, 0]  # Extract zenith angles
Pro_Height_float = [np.array([i[0] for i in x[1]]) for x in x]  # Extract production heights in km
Num_triggered_events = [([i[1] for i in x[1]]) for x in x]  # Extract number of events per production height
for j in range(len(Pro_Height_float[0])):
    mean_prob, ci_bootstrap = detect_prob(Num_triggered_events, j)
    print(f"Production Height: {Pro_Height_float[0][j]} km, Detection Probability: {mean_prob:.4f}, CI: {mean_prob-ci_bootstrap[0]:.4f}, {mean_prob+ci_bootstrap[1]:.4f}")
    x_data.append(Pro_Height_float[0][j])
    y_data.append(mean_prob)
    y_err.append(ci_bootstrap)
    #plt.errorbar(Pro_Height_float[0][j], mean_prob, yerr=[[ci_bootstrap[0]], [ci_bootstrap[1]]], fmt='--o', capsize=10, color='b', label=f'Height: {Pro_Height_float[0][j]} km')
plt.errorbar(x_data, y_data, yerr=np.array(y_err).T, fmt="--o", color='b', capsize=10)
plt.xlabel('Production Height (km)')
plt.ylabel('Detector Sensitivity (Trigger Probability)')
plt.title(f'Detector Sensitivity vs Production Height of 1E{E_mag} GeV Muons for Zenith Angle 88°')
#plt.ylim([0, 1])  # Set y-axis limits to [0, 1]
plt.legend()
plt.grid()
# Out:
# Production Height: 40.0 km, Detection Probability: 0.0200, CI: 0.0000, 0.0500
# /tmp/ipykernel_3090625/175370303.py:42: UserWarning:
#
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
Pro_Height = ["5.E5", "10.E5", "15.E5", "20.E5", "25.E5","30.E5", "40.E5"] #
zenith = [80, 81, 82, 83, 84, 85, 86, 87, 88]  # Zenith angles in degrees  
Events_Data = []
for z in zenith:
    Num_triggered_events = []
    for height in Pro_Height:
        Data_id = []
        for id in range(1, 11):
            h, H, Times, Noise = plot(z, id, production_height=height, noise=True)
            if h is None:
                Trigger_events = 0  # No events triggered
            else:
                Trigger_events = h.max()  # Sum of all pixels with at least 20 PEs
            Data_id.append(Trigger_events)
        height_float = float(height.replace("E", "e")) / 1e5 # Convert to km
        Num_triggered_events.append((height_float, Data_id))
    Events_Data.append((z, Num_triggered_events))
# Out:
# Number of photons in event 0: 248821
# Bright pixel location in cm: (-615.00, -135.00) with value 200.00
# Number of photons in event after optics only 0: 900 of 248821 Ratio: 0.0036170580457437276
# Number of photons: 900
# Number of photons after filtering: 90
# Number of photons after filtering only: 90 of 248821 Ratio: 0.00036170580457437276
# Number of photons in event 0: 1241939
# Bright pixel location in cm: (-135.00, -195.00) with value 1444.00
# Number of photons in event after optics only 0: 22380 of 1241939 Ratio: 0.018020208722006475
# Number of photons: 22380
# Number of photons after filtering: 2218
# Number of photons after filtering only: 2218 of 1241939 Ratio: 0.0017859170216894711
# Number of photons in event 0: 74731
# Bright pixel location in cm: (-705.00, 405.00) with value 203.00
# Number of photons in event after optics only 0: 443 of 74731 Ratio: 0.005927928169032932
# Number of photons: 443
# Number of photons after filtering: 37
# Number of photons after filtering only: 37 of 74731 Ratio: 0.0004951091247273555
# Number of photons in event 0: 864731
# Bright pixel location in cm: (-165.00, -195.00) with value 365.00
# Number of photons in event after optics only 0: 5224 of 864731 Ratio: 0.006041185062175405
# Number of photons: 5224
# Number of photons after filtering: 524
# Number of photons after filtering only: 524 of 864731 Ratio: 0.0006059687926071808
# Number of photons in event 0: 390865
# Bright pixel location in cm: (-105.00, -165.00) with value 1096.00
# Number of photons in event after optics only 0: 16551 of 390865 Ratio: 0.04234454351246594
# Number of photons: 16551
# Number of photons after filtering: 1622
# Number of photons after filtering only: 1622 of 390865 Ratio: 0.004149770381077866
# Number of photons in event 0: 1339306
# Bright pixel location in cm: (-75.00, -285.00) with value 1067.00
# Number of photons in event after optics only 0: 17274 of 1339306 Ratio: 0.012897724642464083
# Number of photons: 17274
# Number of photons after filtering: 1687
# Number of photons after filtering only: 1687 of 1339306 Ratio: 0.0012596075878104033
# Number of photons in event 0: 38190
# Bright pixel location in cm: (225.00, -105.00) with value 117.00
# Number of photons in event after optics only 0: 748 of 38190 Ratio: 0.019586279130662475
# Number of photons: 748
# Number of photons after filtering: 73
# Number of photons after filtering only: 73 of 38190 Ratio: 0.0019114951557999476
# Number of photons in event 0: 294331
# Bright pixel location in cm: (-105.00, -165.00) with value 1009.00
# Number of photons in event after optics only 0: 10262 of 294331 Ratio: 0.03486550856009051
# Number of photons: 10262
# Number of photons after filtering: 1027
# Number of photons after filtering only: 1027 of 294331 Ratio: 0.0034892688843512916
# Number of photons in event 0: 1342068
# Bright pixel location in cm: (-105.00, -165.00) with value 1631.00
# Number of photons in event after optics only 0: 28701 of 1342068 Ratio: 0.02138565258988367
# Number of photons: 28701
# Number of photons after filtering: 2879
# Number of photons after filtering only: 2879 of 1342068 Ratio: 0.0021451968156606075
# Number of photons in event 0: 241857
# Bright pixel location in cm: (-165.00, -135.00) with value 199.00
# Number of photons in event after optics only 0: 2457 of 241857 Ratio: 0.01015889554571503
# Number of photons: 2457
# Number of photons after filtering: 246
# Number of photons after filtering only: 246 of 241857 Ratio: 0.0010171299569580372
# Number of photons in event 0: 30614
# Bright pixel location in cm: (-45.00, -225.00) with value 162.00
# Number of photons in event after optics only 0: 1807 of 30614 Ratio: 0.05902528255046711
# Number of photons: 1807
# Number of photons after filtering: 196
# Number of photons after filtering only: 196 of 30614 Ratio: 0.006402299601489515
# Number of photons in event 0: 38682
# Bright pixel location in cm: (-105.00, -165.00) with value 1266.00
# Number of photons in event after optics only 0: 10360 of 38682 Ratio: 0.2678248280854144
# Number of photons: 10360
# Number of photons after filtering: 1006
# Number of photons after filtering only: 1006 of 38682 Ratio: 0.02600692828705858
# Number of photons in event 0: 15574
# Bright pixel location in cm: (-105.00, -165.00) with value 94.00
# Number of photons in event after optics only 0: 668 of 15574 Ratio: 0.04289199948632336
# Number of photons: 668
# Number of photons after filtering: 62
# Number of photons after filtering only: 62 of 15574 Ratio: 0.003980993964299473
# Number of photons in event 0: 115986
# Bright pixel location in cm: (-105.00, -165.00) with value 367.00
# Number of photons in event after optics only 0: 5128 of 115986 Ratio: 0.04421223251082027
# Number of photons: 5128
# Number of photons after filtering: 472
# Number of photons after filtering only: 472 of 115986 Ratio: 0.00406945665856224
# Number of photons in event 0: 58591
# Bright pixel location in cm: (-165.00, 645.00) with value 168.00
# Number of photons in event after optics only 0: 137 of 58591 Ratio: 0.0023382430748749806
# Number of photons: 137
# Number of photons after filtering: 6
# Number of photons after filtering only: 6 of 58591 Ratio: 0.00010240480619890427
# Number of photons in event 0: 20584
# Bright pixel location in cm: (-105.00, -165.00) with value 105.00
# Number of photons in event after optics only 0: 663 of 20584 Ratio: 0.03220948309366498
# Number of photons: 663
# Number of photons after filtering: 70
# Number of photons after filtering only: 70 of 20584 Ratio: 0.003400699572483482
# Number of photons in event 0: 32035
# Bright pixel location in cm: (-105.00, -165.00) with value 615.00
# Number of photons in event after optics only 0: 5074 of 32035 Ratio: 0.15838926174496645
# Number of photons: 5074
# Number of photons after filtering: 519
# Number of photons after filtering only: 519 of 32035 Ratio: 0.016201030123302637
# Number of photons in event 0: 3671025
# Bright pixel location in cm: (-105.00, -225.00) with value 1917.00
# Number of photons in event after optics only 0: 36091 of 3671025 Ratio: 0.009831314142507883
# Number of photons: 36091
# Number of photons after filtering: 3594
# Number of photons after filtering only: 3594 of 3671025 Ratio: 0.0009790181216417758
# Number of photons in event 0: 1021249
# Bright pixel location in cm: (-45.00, -195.00) with value 924.00
# Number of photons in event after optics only 0: 16284 of 1021249 Ratio: 0.015945180852074275
# Number of photons: 16284
# Number of photons after filtering: 1611
# Number of photons after filtering only: 1611 of 1021249 Ratio: 0.0015774801248275396
# Number of photons in event 0: 11656
# Bright pixel location in cm: (-105.00, -165.00) with value 115.00
# Number of photons in event after optics only 0: 631 of 11656 Ratio: 0.05413520933424846
# Number of photons: 631
# Number of photons after filtering: 70
# Number of photons after filtering only: 70 of 11656 Ratio: 0.006005490734385724
# Number of photons in event 0: 57013
# Bright pixel location in cm: (-45.00, -165.00) with value 333.00
# Number of photons in event after optics only 0: 3728 of 57013 Ratio: 0.06538859558346342
# Number of photons: 3728
# Number of photons after filtering: 361
# Number of photons after filtering only: 361 of 57013 Ratio: 0.00633188921824847
# Number of photons in event 0: 1990675
# Bright pixel location in cm: (-135.00, -225.00) with value 2368.00
# Number of photons in event after optics only 0: 42227 of 1990675 Ratio: 0.02121240282818642
# Number of photons: 42227
# Number of photons after filtering: 4061
# Number of photons after filtering only: 4061 of 1990675 Ratio: 0.0020400115538699187
# Number of photons in event 0: 3199562
# Bright pixel location in cm: (-105.00, -165.00) with value 3332.00
# Number of photons in event after optics only 0: 55215 of 3199562 Ratio: 0.017257049558658342
# Number of photons: 55215
# Number of photons after filtering: 5547
# Number of photons after filtering only: 5547 of 3199562 Ratio: 0.0017336747967378035
# Number of photons in event 0: 251244
# Bright pixel location in cm: (-225.00, -45.00) with value 408.00
# Number of photons in event after optics only 0: 5102 of 251244 Ratio: 0.020306952603843277
# Number of photons: 5102
# Number of photons after filtering: 482
# Number of photons after filtering only: 482 of 251244 Ratio: 0.001918453774020474
# Number of photons in event 0: 525442
# Bright pixel location in cm: (-105.00, -165.00) with value 5034.00
# Number of photons in event after optics only 0: 53530 of 525442 Ratio: 0.10187613475892678
# Number of photons: 53530
# Number of photons after filtering: 5333
# Number of photons after filtering only: 5333 of 525442 Ratio: 0.010149550283380469
# Number of photons in event 0: 6994
# Bright pixel location in cm: (-105.00, -165.00) with value 110.00
# Number of photons in event after optics only 0: 618 of 6994 Ratio: 0.08836145267372034
# Number of photons: 618
# Number of photons after filtering: 57
# Number of photons after filtering only: 57 of 6994 Ratio: 0.008149842722333428
# Number of photons in event 0: 495299
# Bright pixel location in cm: (-105.00, -165.00) with value 1782.00
# Number of photons in event after optics only 0: 13702 of 495299 Ratio: 0.02766409784796658
# Number of photons: 13702
# Number of photons after filtering: 1383
# Number of photons after filtering only: 1383 of 495299 Ratio: 0.0027922527604537866
# Number of photons in event 0: 179676
# Bright pixel location in cm: (-285.00, 1065.00) with value 159.00
# Number of photons in event after optics only 0: 585 of 179676 Ratio: 0.003255860548988179
# Number of photons: 585
# Number of photons after filtering: 48
# Number of photons after filtering only: 48 of 179676 Ratio: 0.0002671475322246711
# Number of photons in event 0: 32712
# Bright pixel location in cm: (225.00, -375.00) with value 131.00
# Number of photons in event after optics only 0: 743 of 32712 Ratio: 0.022713377353876255
# Number of photons: 743
# Number of photons after filtering: 82
# Number of photons after filtering only: 82 of 32712 Ratio: 0.0025067253607238935
# Number of photons in event 0: 15091
# Bright pixel location in cm: (-105.00, -165.00) with value 106.00
# Number of photons in event after optics only 0: 646 of 15091 Ratio: 0.04280697104234312
# Number of photons: 646
# Number of photons after filtering: 64
# Number of photons after filtering only: 64 of 15091 Ratio: 0.004240938307600557
# Number of photons in event 0: 170039
# Bright pixel location in cm: (255.00, 75.00) with value 220.00
# Number of photons in event after optics only 0: 1955 of 170039 Ratio: 0.01149736236980928
# Number of photons: 1955
# Number of photons after filtering: 205
# Number of photons after filtering only: 205 of 170039 Ratio: 0.0012056057727933003
# Number of photons in event 0: 1047044
# Bright pixel location in cm: (75.00, -45.00) with value 444.00
# Number of photons in event after optics only 0: 7994 of 1047044 Ratio: 0.0076348271896883035
# Number of photons: 7994
# Number of photons after filtering: 790
# Number of photons after filtering only: 790 of 1047044 Ratio: 0.0007545050637795546
# Number of photons in event 0: 934834
# Bright pixel location in cm: (-105.00, -165.00) with value 11125.00
# Number of photons in event after optics only 0: 119003 of 934834 Ratio: 0.12729853642464867
# Number of photons: 119003
# Number of photons after filtering: 12178
# Number of photons after filtering only: 12178 of 934834 Ratio: 0.013026911729783042
# Number of photons in event 0: 222387
# Bright pixel location in cm: (-105.00, -195.00) with value 289.00
# Number of photons in event after optics only 0: 3294 of 222387 Ratio: 0.014812016889476453
# Number of photons: 3294
# Number of photons after filtering: 316
# Number of photons after filtering only: 316 of 222387 Ratio: 0.0014209463682679294
# Number of photons in event 0: 4326980
# Bright pixel location in cm: (-105.00, -165.00) with value 9074.00
# Number of photons in event after optics only 0: 141277 of 4326980 Ratio: 0.03265025491220205
# Number of photons: 141277
# Number of photons after filtering: 14302
# Number of photons after filtering only: 14302 of 4326980 Ratio: 0.0033053076279529834
# Number of photons in event 0: 210280
# Bright pixel location in cm: (135.00, 495.00) with value 255.00
# Number of photons in event after optics only 0: 1779 of 210280 Ratio: 0.008460148373597109
# Number of photons: 1779
# Number of photons after filtering: 196
# Number of photons after filtering only: 196 of 210280 Ratio: 0.0009320905459387483
# Number of photons in event 0: 1049019
# Bright pixel location in cm: (-135.00, -225.00) with value 638.00
# Number of photons in event after optics only 0: 9064 of 1049019 Ratio: 0.008640453604748818
# Number of photons: 9064
# Number of photons after filtering: 939
# Number of photons after filtering only: 939 of 1049019 Ratio: 0.0008951220139959334
# Number of photons in event 0: 2660414
# Bright pixel location in cm: (-105.00, -165.00) with value 10961.00
# Number of photons in event after optics only 0: 143402 of 2660414 Ratio: 0.05390213703581473
# Number of photons: 143402
# Number of photons after filtering: 14253
# Number of photons after filtering only: 14253 of 2660414 Ratio: 0.005357436850054164
# Number of photons in event 0: 29893
# Bright pixel location in cm: (705.00, 1425.00) with value 103.00
# Number of photons in event after optics only 0: 222 of 29893 Ratio: 0.007426487806509886
# Number of photons: 222
# Number of photons after filtering: 16
# Number of photons after filtering only: 16 of 29893 Ratio: 0.0005352423644331449
# Number of photons in event 0: 9414
# Bright pixel location in cm: (-105.00, -165.00) with value 103.00
# Number of photons in event after optics only 0: 632 of 9414 Ratio: 0.06713405566178032
# Number of photons: 632
# Number of photons after filtering: 65
# Number of photons after filtering only: 65 of 9414 Ratio: 0.0069046101550881665
# Number of photons in event 0: 183350
# Bright pixel location in cm: (-45.00, -45.00) with value 297.00
# Number of photons in event after optics only 0: 2280 of 183350 Ratio: 0.012435233160621761
# Number of photons: 2280
# Number of photons after filtering: 247
# Number of photons after filtering only: 247 of 183350 Ratio: 0.0013471502590673575
# Number of photons in event 0: 907207
# Bright pixel location in cm: (-135.00, -165.00) with value 2100.00
# Number of photons in event after optics only 0: 28730 of 907207 Ratio: 0.03166862689551558
# Number of photons: 28730
# Number of photons after filtering: 2870
# Number of photons after filtering only: 2870 of 907207 Ratio: 0.0031635558367605187
# Number of photons in event 0: 944893
# Bright pixel location in cm: (-75.00, -45.00) with value 392.00
# Number of photons in event after optics only 0: 5367 of 944893 Ratio: 0.005680008212570101
# Number of photons: 5367
# Number of photons after filtering: 534
# Number of photons after filtering only: 534 of 944893 Ratio: 0.0005651433548560525
# Number of photons in event 0: 245725
# Bright pixel location in cm: (105.00, -15.00) with value 211.00
# Number of photons in event after optics only 0: 2556 of 245725 Ratio: 0.010401872011394852
# Number of photons: 2556
# Number of photons after filtering: 256
# Number of photons after filtering only: 256 of 245725 Ratio: 0.0010418150371350086
# Number of photons in event 0: 2885673
# Bright pixel location in cm: (-105.00, -195.00) with value 3987.00
# Number of photons in event after optics only 0: 68135 of 2885673 Ratio: 0.02361147642161811
# Number of photons: 68135
# Number of photons after filtering: 6846
# Number of photons after filtering only: 6846 of 2885673 Ratio: 0.0023724101795317763
# Number of photons in event 0: 58917
# Bright pixel location in cm: (-105.00, -165.00) with value 364.00
# Number of photons in event after optics only 0: 4495 of 58917 Ratio: 0.07629376920074002
# Number of photons: 4495
# Number of photons after filtering: 430
# Number of photons after filtering only: 430 of 58917 Ratio: 0.007298402837890592
# Number of photons in event 0: 1571361
# Bright pixel location in cm: (-75.00, -105.00) with value 1196.00
# Number of photons in event after optics only 0: 19823 of 1571361 Ratio: 0.012615178816325465
# Number of photons: 19823
# Number of photons after filtering: 2008
# Number of photons after filtering only: 2008 of 1571361 Ratio: 0.0012778731303627875
# Number of photons in event 0: 3227270
# Bright pixel location in cm: (-105.00, -165.00) with value 2364.00
# Number of photons in event after optics only 0: 39970 of 3227270 Ratio: 0.012385080888800751
# Number of photons: 39970
# Number of photons after filtering: 4089
# Number of photons after filtering only: 4089 of 3227270 Ratio: 0.001267015155224075
# Number of photons in event 0: 132991
# Bright pixel location in cm: (-105.00, -165.00) with value 455.00
# Number of photons in event after optics only 0: 5389 of 132991 Ratio: 0.04052153905151477
# Number of photons: 5389
# Number of photons after filtering: 554
# Number of photons after filtering only: 554 of 132991 Ratio: 0.004165695422998549
# Number of photons in event 0: 7827
# Bright pixel location in cm: (-105.00, -165.00) with value 97.00
# Number of photons in event after optics only 0: 636 of 7827 Ratio: 0.08125718666155615
# Number of photons: 636
# Number of photons after filtering: 93
# Number of photons after filtering only: 93 of 7827 Ratio: 0.011881947106170947
# Number of photons in event 0: 33280
# Bright pixel location in cm: (-105.00, -165.00) with value 107.00
# Number of photons in event after optics only 0: 712 of 33280 Ratio: 0.02139423076923077
# Number of photons: 712
# Number of photons after filtering: 69
# Number of photons after filtering only: 69 of 33280 Ratio: 0.0020733173076923077
# Number of photons in event 0: 1002251
# Bright pixel location in cm: (-75.00, -225.00) with value 1849.00
# Number of photons in event after optics only 0: 31304 of 1002251 Ratio: 0.031233692957153447
# Number of photons: 31304
# Number of photons after filtering: 3117
# Number of photons after filtering only: 3117 of 1002251 Ratio: 0.0031099993913700262
# Number of photons in event 0: 1185208
# Bright pixel location in cm: (-195.00, 15.00) with value 516.00
# Number of photons in event after optics only 0: 6479 of 1185208 Ratio: 0.0054665510188928864
# Number of photons: 6479
# Number of photons after filtering: 616
# Number of photons after filtering only: 616 of 1185208 Ratio: 0.0005197399950050962
# Number of photons in event 0: 230712
# Bright pixel location in cm: (135.00, -105.00) with value 266.00
# Number of photons in event after optics only 0: 2305 of 230712 Ratio: 0.009990811054474844
# Number of photons: 2305
# Number of photons after filtering: 220
# Number of photons after filtering only: 220 of 230712 Ratio: 0.0009535698186483581
# Number of photons in event 0: 2731912
# Bright pixel location in cm: (-105.00, -195.00) with value 4105.00
# Number of photons in event after optics only 0: 70908 of 2731912 Ratio: 0.025955448052499493
# Number of photons: 70908
# Number of photons after filtering: 6983
# Number of photons after filtering only: 6983 of 2731912 Ratio: 0.002556085261897162
# Number of photons in event 0: 103947
# Bright pixel location in cm: (-105.00, -165.00) with value 319.00
# Number of photons in event after optics only 0: 4230 of 103947 Ratio: 0.040693815117319405
# Number of photons: 4230
# Number of photons after filtering: 397
# Number of photons after filtering only: 397 of 103947 Ratio: 0.003819254042925722
# Number of photons in event 0: 938925
# Bright pixel location in cm: (-105.00, -165.00) with value 644.00
# Number of photons in event after optics only 0: 9153 of 938925 Ratio: 0.009748382458662833
# Number of photons: 9153
# Number of photons after filtering: 881
# Number of photons after filtering only: 881 of 938925 Ratio: 0.0009383071065314056
# Number of photons in event 0: 2824350
# Bright pixel location in cm: (-105.00, -165.00) with value 4342.00
# Number of photons in event after optics only 0: 65102 of 2824350 Ratio: 0.02305025935170924
# Number of photons: 65102
# Number of photons after filtering: 6333
# Number of photons after filtering only: 6333 of 2824350 Ratio: 0.0022422858356790057
# Number of photons in event 0: 173079
# Bright pixel location in cm: (-105.00, -195.00) with value 1043.00
# Number of photons in event after optics only 0: 9827 of 173079 Ratio: 0.05677754089173152
# Number of photons: 9827
# Number of photons after filtering: 968
# Number of photons after filtering only: 968 of 173079 Ratio: 0.0055928217750275885
# Number of photons in event 0: 8050
# Bright pixel location in cm: (-105.00, -165.00) with value 117.00
# Number of photons in event after optics only 0: 632 of 8050 Ratio: 0.07850931677018634
# Number of photons: 632
# Number of photons after filtering: 66
# Number of photons after filtering only: 66 of 8050 Ratio: 0.008198757763975155
# Number of photons in event 0: 180166
# Bright pixel location in cm: (15.00, -75.00) with value 241.00
# Number of photons in event after optics only 0: 2750 of 180166 Ratio: 0.015263701253288634
# Number of photons: 2750
# Number of photons after filtering: 295
# Number of photons after filtering only: 295 of 180166 Ratio: 0.001637378861716417
# Number of photons in event 0: 1300379
# Bright pixel location in cm: (-165.00, -225.00) with value 1498.00
# Number of photons in event after optics only 0: 23559 of 1300379 Ratio: 0.018117025882454268
# Number of photons: 23559
# Number of photons after filtering: 2416
# Number of photons after filtering only: 2416 of 1300379 Ratio: 0.0018579198833570828
# Number of photons in event 0: 3885601
# Bright pixel location in cm: (-105.00, -165.00) with value 3045.00
# Number of photons in event after optics only 0: 50345 of 3885601 Ratio: 0.012956811571749133
# Number of photons: 50345
# Number of photons after filtering: 5037
# Number of photons after filtering only: 5037 of 3885601 Ratio: 0.0012963245582858353
# Number of photons in event 0: 70344
# Bright pixel location in cm: (-105.00, -195.00) with value 383.00
# Number of photons in event after optics only 0: 2480 of 70344 Ratio: 0.035255316729216425
# Number of photons: 2480
# Number of photons after filtering: 247
# Number of photons after filtering only: 247 of 70344 Ratio: 0.003511315819401797
# Number of photons in event 0: 3225709
# Bright pixel location in cm: (-105.00, -165.00) with value 1809.00
# Number of photons in event after optics only 0: 31297 of 3225709 Ratio: 0.009702363108389504
# Number of photons: 31297
# Number of photons after filtering: 3068
# Number of photons after filtering only: 3068 of 3225709 Ratio: 0.0009511087329948238
# Number of photons in event 0: 101047
# Bright pixel location in cm: (-105.00, 75.00) with value 398.00
# Number of photons in event after optics only 0: 4651 of 101047 Ratio: 0.04602808594020604
# Number of photons: 4651
# Number of photons after filtering: 446
# Number of photons after filtering only: 446 of 101047 Ratio: 0.004413787643373876
# Number of photons in event 0: 697081
# Bright pixel location in cm: (-15.00, -165.00) with value 563.00
# Number of photons in event after optics only 0: 7145 of 697081 Ratio: 0.010249884877080282
# Number of photons: 7145
# Number of photons after filtering: 669
# Number of photons after filtering only: 669 of 697081 Ratio: 0.0009597163026965303
# Number of photons in event 0: 1809666
# Bright pixel location in cm: (-105.00, -165.00) with value 14924.00
# Number of photons in event after optics only 0: 169333 of 1809666 Ratio: 0.09357141041496055
# Number of photons: 169333
# Number of photons after filtering: 16832
# Number of photons after filtering only: 16832 of 1809666 Ratio: 0.009301163861176593
# Number of photons in event 0: 53065
# Bright pixel location in cm: (-855.00, -45.00) with value 151.00
# Number of photons in event after optics only 0: 213 of 53065 Ratio: 0.0040139451615942715
# Number of photons: 213
# Number of photons after filtering: 22
# Number of photons after filtering only: 22 of 53065 Ratio: 0.00041458588523508904
# Number of photons in event 0: 7856
# Bright pixel location in cm: (-105.00, -165.00) with value 100.00
# Number of photons in event after optics only 0: 645 of 7856 Ratio: 0.08210285132382893
# Number of photons: 645
# Number of photons after filtering: 71
# Number of photons after filtering only: 71 of 7856 Ratio: 0.009037678207739307
# Number of photons in event 0: 2620678
# Bright pixel location in cm: (-135.00, -195.00) with value 3549.00
# Number of photons in event after optics only 0: 54562 of 2620678 Ratio: 0.020819803119650718
# Number of photons: 54562
# Number of photons after filtering: 4806
# Number of photons after filtering only: 4806 of 2620678 Ratio: 0.001833876576977408
# Number of photons in event 0: 805538
# Bright pixel location in cm: (-135.00, -165.00) with value 901.00
# Number of photons in event after optics only 0: 15571 of 805538 Ratio: 0.019329938500728706
# Number of photons: 15571
# Number of photons after filtering: 1420
# Number of photons after filtering only: 1420 of 805538 Ratio: 0.0017627970375078518
# Number of photons in event 0: 20883
# Bright pixel location in cm: (-435.00, 1035.00) with value 127.00
# Number of photons in event after optics only 0: 492 of 20883 Ratio: 0.023559833357276252
# Number of photons: 492
# Number of photons after filtering: 43
# Number of photons after filtering only: 43 of 20883 Ratio: 0.0020590911267538187
# Number of photons in event 0: 117735
# Bright pixel location in cm: (-135.00, -195.00) with value 836.00
# Number of photons in event after optics only 0: 6413 of 117735 Ratio: 0.05446978383658215
# Number of photons: 6413
# Number of photons after filtering: 564
# Number of photons after filtering only: 564 of 117735 Ratio: 0.004790419161676647
# Number of photons in event 0: 164104
# Bright pixel location in cm: (-165.00, -195.00) with value 347.00
# Number of photons in event after optics only 0: 5638 of 164104 Ratio: 0.03435626188270852
# Number of photons: 5638
# Number of photons after filtering: 480
# Number of photons after filtering only: 480 of 164104 Ratio: 0.0029249744064739434
# Number of photons in event 0: 697927
# Bright pixel location in cm: (-135.00, -195.00) with value 540.00
# Number of photons in event after optics only 0: 7721 of 697927 Ratio: 0.011062761578216633
# Number of photons: 7721
# Number of photons after filtering: 648
# Number of photons after filtering only: 648 of 697927 Ratio: 0.0009284638651320267
# Number of photons in event 0: 19297
# Bright pixel location in cm: (195.00, -705.00) with value 153.00
# Number of photons in event after optics only 0: 123 of 19297 Ratio: 0.006374047779447583
# Number of photons: 123
# Number of photons after filtering: 11
# Number of photons after filtering only: 11 of 19297 Ratio: 0.0005700367932839302
# Number of photons in event 0: 449173
# Bright pixel location in cm: (-135.00, -195.00) with value 547.00
# Number of photons in event after optics only 0: 8284 of 449173 Ratio: 0.01844278262495742
# Number of photons: 8284
# Number of photons after filtering: 743
# Number of photons after filtering only: 743 of 449173 Ratio: 0.0016541510731945153
# Number of photons in event 0: 341710
# Bright pixel location in cm: (-135.00, -195.00) with value 849.00
# Number of photons in event after optics only 0: 6171 of 341710 Ratio: 0.01805917298293875
# Number of photons: 6171
# Number of photons after filtering: 521
# Number of photons after filtering only: 521 of 341710 Ratio: 0.0015246846741388898
# Number of photons in event 0: 79067
# Bright pixel location in cm: (285.00, 105.00) with value 125.00
# Number of photons in event after optics only 0: 697 of 79067 Ratio: 0.008815308535798753
# Number of photons: 697
# Number of photons after filtering: 55
# Number of photons after filtering only: 55 of 79067 Ratio: 0.0006956125817344784
# Number of photons in event 0: 25002
# Bright pixel location in cm: (-135.00, -195.00) with value 108.00
# Number of photons in event after optics only 0: 683 of 25002 Ratio: 0.027317814574834013
# Number of photons: 683
# Number of photons after filtering: 50
# Number of photons after filtering only: 50 of 25002 Ratio: 0.001999840012798976
# Number of photons in event 0: 1011914
# Bright pixel location in cm: (-75.00, -165.00) with value 563.00
# Number of photons in event after optics only 0: 8322 of 1011914 Ratio: 0.008224019037190907
# Number of photons: 8322
# Number of photons after filtering: 707
# Number of photons after filtering only: 707 of 1011914 Ratio: 0.0006986759744405157
# Number of photons in event 0: 84357
# Bright pixel location in cm: (-135.00, -195.00) with value 345.00
# Number of photons in event after optics only 0: 2384 of 84357 Ratio: 0.028260843794824377
# Number of photons: 2384
# Number of photons after filtering: 213
# Number of photons after filtering only: 213 of 84357 Ratio: 0.0025249831075073795
# Number of photons in event 0: 28977
# Bright pixel location in cm: (-135.00, -195.00) with value 104.00
# Number of photons in event after optics only 0: 695 of 28977 Ratio: 0.023984539462332196
# Number of photons: 695
# Number of photons after filtering: 60
# Number of photons after filtering only: 60 of 28977 Ratio: 0.002070607723366808
# Number of photons in event 0: 11259
# Bright pixel location in cm: (-135.00, -195.00) with value 109.00
# Number of photons in event after optics only 0: 640 of 11259 Ratio: 0.05684341415756284
# Number of photons: 640
# Number of photons after filtering: 73
# Number of photons after filtering only: 73 of 11259 Ratio: 0.006483701927347011
# Number of photons in event 0: 55429
# Bright pixel location in cm: (-135.00, -285.00) with value 272.00
# Number of photons in event after optics only 0: 2465 of 55429 Ratio: 0.044471305634234785
# Number of photons: 2465
# Number of photons after filtering: 193
# Number of photons after filtering only: 193 of 55429 Ratio: 0.0034819318407331903
# Number of photons in event 0: 316568
# Bright pixel location in cm: (-135.00, -195.00) with value 2359.00
# Number of photons in event after optics only 0: 26944 of 316568 Ratio: 0.08511283515705946
# Number of photons: 26944
# Number of photons after filtering: 2337
# Number of photons after filtering only: 2337 of 316568 Ratio: 0.007382300169315913
# Number of photons in event 0: 801793
# Bright pixel location in cm: (-45.00, -765.00) with value 302.00
# Number of photons in event after optics only 0: 3701 of 801793 Ratio: 0.004615904603806718
# Number of photons: 3701
# Number of photons after filtering: 320
# Number of photons after filtering only: 320 of 801793 Ratio: 0.00039910550478739523
# Number of photons in event 0: 61990
# Bright pixel location in cm: (-375.00, 465.00) with value 220.00
# Number of photons in event after optics only 0: 996 of 61990 Ratio: 0.016067107597999678
# Number of photons: 996
# Number of photons after filtering: 100
# Number of photons after filtering only: 100 of 61990 Ratio: 0.0016131634134537829
# Number of photons in event 0: 198246
# Bright pixel location in cm: (-135.00, -195.00) with value 1320.00
# Number of photons in event after optics only 0: 14547 of 198246 Ratio: 0.07337852970551739
# Number of photons: 14547
# Number of photons after filtering: 1310
# Number of photons after filtering only: 1310 of 198246 Ratio: 0.006607951736731132
# Number of photons in event 0: 213164
# Bright pixel location in cm: (-675.00, -345.00) with value 330.00
# Number of photons in event after optics only 0: 1610 of 213164 Ratio: 0.0075528700906344415
# Number of photons: 1610
# Number of photons after filtering: 123
# Number of photons after filtering only: 123 of 213164 Ratio: 0.0005770205100298362
# Number of photons in event 0: 1180526
# Bright pixel location in cm: (-105.00, -225.00) with value 942.00
# Number of photons in event after optics only 0: 17213 of 1180526 Ratio: 0.014580788563741925
# Number of photons: 17213
# /uufs/chpc.utah.edu/common/home/u1520754/test_jupyter/read_telescope.py:544: RuntimeWarning:
#
# invalid value encountered in sqrt
# Number of photons after filtering: 1529
# Number of photons after filtering only: 1529 of 1180526 Ratio: 0.0012951853665230583
# Number of photons in event 0: 2288091
# Bright pixel location in cm: (-255.00, -105.00) with value 1035.00
# Number of photons in event after optics only 0: 16533 of 2288091 Ratio: 0.007225674153694062
# Number of photons: 16533
# Number of photons after filtering: 1377
# Number of photons after filtering only: 1377 of 2288091 Ratio: 0.0006018117286419115
# Number of photons in event 0: 77102
# Bright pixel location in cm: (255.00, 195.00) with value 148.00
# Number of photons in event after optics only 0: 444 of 77102 Ratio: 0.0057586054836450415
# Number of photons: 444
# Number of photons after filtering: 29
# Number of photons after filtering only: 29 of 77102 Ratio: 0.00037612513294077974
# Number of photons in event 0: 1935229
# Bright pixel location in cm: (-135.00, -195.00) with value 9477.00
# Number of photons in event after optics only 0: 106707 of 1935229 Ratio: 0.05513921091509067
# Number of photons: 106707
# Number of photons after filtering: 9324
# Number of photons after filtering only: 9324 of 1935229 Ratio: 0.004818034454837128
# Number of photons in event 0: 14402
# Bright pixel location in cm: (-795.00, -585.00) with value 138.00
# Number of photons in event after optics only 0: 255 of 14402 Ratio: 0.01770587418414109
# Number of photons: 255
# Number of photons after filtering: 25
# Number of photons after filtering only: 25 of 14402 Ratio: 0.0017358700180530482
# Number of photons in event 0: 1591009
# Bright pixel location in cm: (-105.00, -255.00) with value 1097.00
# Number of photons in event after optics only 0: 21155 of 1591009 Ratio: 0.013296593545353922
# Number of photons: 21155
# Number of photons after filtering: 1809
# Number of photons after filtering only: 1809 of 1591009 Ratio: 0.0011370143097870597
# Number of photons in event 0: 3225331
# Bright pixel location in cm: (-135.00, -195.00) with value 8320.00
# Number of photons in event after optics only 0: 124333 of 3225331 Ratio: 0.038548911724099015
# Number of photons: 124333
# Number of photons after filtering: 10891
# Number of photons after filtering only: 10891 of 3225331 Ratio: 0.0033767076929468636
# Number of photons in event 0: 201797
# Bright pixel location in cm: (-75.00, -225.00) with value 514.00
# Number of photons in event after optics only 0: 8934 of 201797 Ratio: 0.04427221415581005
# Number of photons: 8934
# Number of photons after filtering: 728
# Number of photons after filtering only: 728 of 201797 Ratio: 0.0036075858412166683
# Number of photons in event 0: 11791
# Bright pixel location in cm: (-135.00, -195.00) with value 111.00
# Number of photons in event after optics only 0: 634 of 11791 Ratio: 0.0537698244423713
# Number of photons: 634
# Number of photons after filtering: 61
# Number of photons after filtering only: 61 of 11791 Ratio: 0.005173437367483674
# Number of photons in event 0: 71516
# Bright pixel location in cm: (-225.00, -285.00) with value 399.00
# Number of photons in event after optics only 0: 3985 of 71516 Ratio: 0.05572179652105822
# Number of photons: 3985
# Number of photons after filtering: 325
# Number of photons after filtering only: 325 of 71516 Ratio: 0.004544437608367358
# Number of photons in event 0: 71114
# Bright pixel location in cm: (-135.00, -195.00) with value 341.00
# Number of photons in event after optics only 0: 2262 of 71114 Ratio: 0.03180808279663638
# Number of photons: 2262
# Number of photons after filtering: 191
# Number of photons after filtering only: 191 of 71114 Ratio: 0.0026858283882217285
# Number of photons in event 0: 225536
# Bright pixel location in cm: (-135.00, -195.00) with value 1164.00
# Number of photons in event after optics only 0: 10257 of 225536 Ratio: 0.04547832718501703
# Number of photons: 10257
# Number of photons after filtering: 923
# Number of photons after filtering only: 923 of 225536 Ratio: 0.00409247304199773
# Number of photons in event 0: 87101
# Bright pixel location in cm: (-135.00, -195.00) with value 881.00
# Number of photons in event after optics only 0: 6948 of 87101 Ratio: 0.07976946303716376
# Number of photons: 6948
# Number of photons after filtering: 607
# Number of photons after filtering only: 607 of 87101 Ratio: 0.006968921137529994
# Number of photons in event 0: 1600863
# Bright pixel location in cm: (-105.00, -75.00) with value 784.00
# Number of photons in event after optics only 0: 12312 of 1600863 Ratio: 0.007690851746839048
# Number of photons: 12312
# Number of photons after filtering: 1113
# Number of photons after filtering only: 1113 of 1600863 Ratio: 0.0006952499995315027
# Number of photons in event 0: 147046
# Bright pixel location in cm: (-135.00, -195.00) with value 400.00
# Number of photons in event after optics only 0: 4883 of 147046 Ratio: 0.03320729567618296
# Number of photons: 4883
# Number of photons after filtering: 428
# Number of photons after filtering only: 428 of 147046 Ratio: 0.002910653809012146
# Number of photons in event 0: 84974
# Bright pixel location in cm: (-135.00, -195.00) with value 121.00
# Number of photons in event after optics only 0: 863 of 84974 Ratio: 0.01015604773224751
# Number of photons: 863
# Number of photons after filtering: 77
# Number of photons after filtering only: 77 of 84974 Ratio: 0.0009061595311507049
# Number of photons in event 0: 4356458
# Bright pixel location in cm: (-225.00, -345.00) with value 1755.00
# Number of photons in event after optics only 0: 30170 of 4356458 Ratio: 0.006925350823995089
# Number of photons: 30170
# Number of photons after filtering: 2597
# Number of photons after filtering only: 2597 of 4356458 Ratio: 0.0005961264862418047
# Number of photons in event 0: 22002
# Bright pixel location in cm: (-135.00, -195.00) with value 103.00
# Number of photons in event after optics only 0: 674 of 22002 Ratio: 0.030633578765566768
# Number of photons: 674
# Number of photons after filtering: 56
# Number of photons after filtering only: 56 of 22002 Ratio: 0.0025452231615307698
# Number of photons in event 0: 10197
# Bright pixel location in cm: (-585.00, -435.00) with value 136.00
# Number of photons in event after optics only 0: 486 of 10197 Ratio: 0.04766107678729038
# Number of photons: 486
# Number of photons after filtering: 47
# Number of photons after filtering only: 47 of 10197 Ratio: 0.004609198783956065
# Number of photons in event 0: 68567
# Bright pixel location in cm: (-135.00, -195.00) with value 829.00
# Number of photons in event after optics only 0: 6959 of 68567 Ratio: 0.10149197135648344
# Number of photons: 6959
# Number of photons after filtering: 620
# Number of photons after filtering only: 620 of 68567 Ratio: 0.00904225064535418
# Number of photons in event 0: 271094
# Bright pixel location in cm: (-495.00, -585.00) with value 412.00
# Number of photons in event after optics only 0: 3423 of 271094 Ratio: 0.01262661659793282
# Number of photons: 3423
# Number of photons after filtering: 306
# Number of photons after filtering only: 306 of 271094 Ratio: 0.0011287597659852301
# Number of photons in event 0: 1317922
# Bright pixel location in cm: (-135.00, -165.00) with value 3328.00
# Number of photons in event after optics only 0: 52279 of 1317922 Ratio: 0.03966774968473096
# Number of photons: 52279
# Number of photons after filtering: 4498
# Number of photons after filtering only: 4498 of 1317922 Ratio: 0.0034129485660001125
# Number of photons in event 0: 314074
# Bright pixel location in cm: (-465.00, -345.00) with value 361.00
# Number of photons in event after optics only 0: 3853 of 314074 Ratio: 0.012267809497124882
# Number of photons: 3853
# Number of photons after filtering: 348
# Number of photons after filtering only: 348 of 314074 Ratio: 0.0011080191292497947
# Number of photons in event 0: 764141
# Bright pixel location in cm: (-135.00, -195.00) with value 421.00
# Number of photons in event after optics only 0: 5944 of 764141 Ratio: 0.00777866911996608
# Number of photons: 5944
# Number of photons after filtering: 497
# Number of photons after filtering only: 497 of 764141 Ratio: 0.0006504035250038933
# Number of photons in event 0: 21909
# Bright pixel location in cm: (-135.00, -195.00) with value 105.00
# Number of photons in event after optics only 0: 656 of 21909 Ratio: 0.02994203295449359
# Number of photons: 656
# Number of photons after filtering: 62
# Number of photons after filtering only: 62 of 21909 Ratio: 0.0028298872609429913
# Number of photons in event 0: 96036
# Bright pixel location in cm: (-375.00, -1245.00) with value 125.00
# Number of photons in event after optics only 0: 584 of 96036 Ratio: 0.006081052938481403
# Number of photons: 584
# Number of photons after filtering: 44
# Number of photons after filtering only: 44 of 96036 Ratio: 0.0004581615227622975
# Number of photons in event 0: 570489
# Bright pixel location in cm: (-135.00, -195.00) with value 698.00
# Number of photons in event after optics only 0: 6751 of 570489 Ratio: 0.01183370757367802
# Number of photons: 6751
# Number of photons after filtering: 562
# Number of photons after filtering only: 562 of 570489 Ratio: 0.0009851197832035324
# Number of photons in event 0: 47707
# Bright pixel location in cm: (-885.00, -1035.00) with value 136.00
# Number of photons in event after optics only 0: 438 of 47707 Ratio: 0.009181042614291405
# Number of photons: 438
# Number of photons after filtering: 37
# Number of photons after filtering only: 37 of 47707 Ratio: 0.000775567526778041
# Number of photons in event 0: 7892
# Bright pixel location in cm: (-135.00, -195.00) with value 123.00
# Number of photons in event after optics only 0: 626 of 7892 Ratio: 0.07932083122149011
# Number of photons: 626
# Number of photons after filtering: 55
# Number of photons after filtering only: 55 of 7892 Ratio: 0.0069690826153066395
# Number of photons in event 0: 408280
# Bright pixel location in cm: (-135.00, -195.00) with value 1160.00
# Number of photons in event after optics only 0: 11562 of 408280 Ratio: 0.028318800822964632
# Number of photons: 11562
# Number of photons after filtering: 1005
# Number of photons after filtering only: 1005 of 408280 Ratio: 0.0024615459978446163
# Number of photons in event 0: 134848
# Bright pixel location in cm: (-255.00, -255.00) with value 174.00
# Number of photons in event after optics only 0: 712 of 134848 Ratio: 0.005280018984337921
# Number of photons: 712
# Number of photons after filtering: 57
# Number of photons after filtering only: 57 of 134848 Ratio: 0.0004226981490270527
# Number of photons in event 0: 1421665
# Bright pixel location in cm: (-135.00, -165.00) with value 1786.00
# Number of photons in event after optics only 0: 27091 of 1421665 Ratio: 0.0190558253878375
# Number of photons: 27091
# Number of photons after filtering: 2376
# Number of photons after filtering only: 2376 of 1421665 Ratio: 0.001671279802203754
# Number of photons in event 0: 229215
# Bright pixel location in cm: (-525.00, -945.00) with value 197.00
# Number of photons in event after optics only 0: 1914 of 229215 Ratio: 0.008350238858713435
# Number of photons: 1914
# Number of photons after filtering: 147
# Number of photons after filtering only: 147 of 229215 Ratio: 0.000641319285387082
# Number of photons in event 0: 389107
# Bright pixel location in cm: (-765.00, -105.00) with value 308.00
# Number of photons in event after optics only 0: 2655 of 389107 Ratio: 0.006823315951653401
# Number of photons: 2655
# Number of photons after filtering: 233
# Number of photons after filtering only: 233 of 389107 Ratio: 0.0005988070119530103
# Number of photons in event 0: 16612
# Bright pixel location in cm: (-135.00, -195.00) with value 113.00
# Number of photons in event after optics only 0: 645 of 16612 Ratio: 0.03882735372020226
# Number of photons: 645
# Number of photons after filtering: 59
# Number of photons after filtering only: 59 of 16612 Ratio: 0.0035516494100650132
# Number of photons in event 0: 63035
# Bright pixel location in cm: (-135.00, -195.00) with value 115.00
# Number of photons in event after optics only 0: 795 of 63035 Ratio: 0.012612040929642262
# Number of photons: 795
# Number of photons after filtering: 63
# Number of photons after filtering only: 63 of 63035 Ratio: 0.000999444752915047
# Number of photons in event 0: 1355953
# Bright pixel location in cm: (-135.00, -195.00) with value 905.00
# Number of photons in event after optics only 0: 9846 of 1355953 Ratio: 0.007261313629602206
# Number of photons: 9846
# Number of photons after filtering: 842
# Number of photons after filtering only: 842 of 1355953 Ratio: 0.0006209654759420127
# Number of photons in event 0: 37604
# Bright pixel location in cm: (-135.00, -195.00) with value 111.00
# Number of photons in event after optics only 0: 719 of 37604 Ratio: 0.019120306350388257
# Number of photons: 719
# Number of photons after filtering: 61
# Number of photons after filtering only: 61 of 37604 Ratio: 0.0016221678544835656
# Number of photons in event 0: 8895
# Bright pixel location in cm: (-135.00, -195.00) with value 108.00
# Number of photons in event after optics only 0: 629 of 8895 Ratio: 0.07071388420460933
# Number of photons: 629
# Number of photons after filtering: 57
# Number of photons after filtering only: 57 of 8895 Ratio: 0.0064080944350758855
# Number of photons in event 0: 385704
# Bright pixel location in cm: (-135.00, -195.00) with value 460.00
# Number of photons in event after optics only 0: 6327 of 385704 Ratio: 0.01640377076722046
# Number of photons: 6327
# Number of photons after filtering: 539
# Number of photons after filtering only: 539 of 385704 Ratio: 0.0013974446725986767
# Number of photons in event 0: 136877
# Bright pixel location in cm: (135.00, -255.00) with value 242.00
# Number of photons in event after optics only 0: 1138 of 136877 Ratio: 0.008314033767543123
# Number of photons: 1138
# Number of photons after filtering: 78
# Number of photons after filtering only: 78 of 136877 Ratio: 0.000569854687054801
# Number of photons in event 0: 770612
# Bright pixel location in cm: (-75.00, -405.00) with value 353.00
# Number of photons in event after optics only 0: 4669 of 770612 Ratio: 0.006058820781404909
# Number of photons: 4669
# Number of photons after filtering: 369
# Number of photons after filtering only: 369 of 770612 Ratio: 0.000478840194546672
# Number of photons in event 0: 51436
# Bright pixel location in cm: (-105.00, -225.00) with value 342.00
# Number of photons in event after optics only 0: 3507 of 51436 Ratio: 0.06818181818181818
# Number of photons: 3507
# Number of photons after filtering: 319
# Number of photons after filtering only: 319 of 51436 Ratio: 0.006201881950384945
# Number of photons in event 0: 138251
# Bright pixel location in cm: (-135.00, -195.00) with value 130.00
# Number of photons in event after optics only 0: 1066 of 138251 Ratio: 0.007710613304786222
# Number of photons: 1066
# Number of photons after filtering: 88
# Number of photons after filtering only: 88 of 138251 Ratio: 0.0006365234247853542
# Number of photons in event 0: 13732
# Bright pixel location in cm: (-135.00, -195.00) with value 101.00
# Number of photons in event after optics only 0: 664 of 13732 Ratio: 0.04835420914651908
# Number of photons: 664
# Number of photons after filtering: 73
# Number of photons after filtering only: 73 of 13732 Ratio: 0.005316050101951646
# Number of photons in event 0: 1004738
# Bright pixel location in cm: (-135.00, -195.00) with value 5710.00
# Number of photons in event after optics only 0: 60326 of 1004738 Ratio: 0.06004152326278094
# Number of photons: 60326
# Number of photons after filtering: 5230
# Number of photons after filtering only: 5230 of 1004738 Ratio: 0.005205337112759744
# Number of photons in event 0: 4867660
# Bright pixel location in cm: (-135.00, -195.00) with value 5412.00
# Number of photons in event after optics only 0: 87221 of 4867660 Ratio: 0.017918465956948515
# Number of photons: 87221
# Number of photons after filtering: 7525
# Number of photons after filtering only: 7525 of 4867660 Ratio: 0.0015459173401593373
# Number of photons in event 0: 92640
# Bright pixel location in cm: (-135.00, -255.00) with value 228.00
# Number of photons in event after optics only 0: 3111 of 92640 Ratio: 0.03358160621761658
# Number of photons: 3111
# Number of photons after filtering: 262
# Number of photons after filtering only: 262 of 92640 Ratio: 0.002828151986183074
# Number of photons in event 0: 7841
# Bright pixel location in cm: (-135.00, -195.00) with value 110.00
# Number of photons in event after optics only 0: 633 of 7841 Ratio: 0.08072949878841984
# Number of photons: 633
# Number of photons after filtering: 34
# Number of photons after filtering only: 34 of 7841 Ratio: 0.004336181609488586
# Number of photons in event 0: 109784
# Bright pixel location in cm: (255.00, 1305.00) with value 170.00
# Number of photons in event after optics only 0: 461 of 109784 Ratio: 0.004199154703781972
# Number of photons: 461
# Number of photons after filtering: 27
# Number of photons after filtering only: 27 of 109784 Ratio: 0.0002459374772280114
# Number of photons in event 0: 7582
# Bright pixel location in cm: (-135.00, -225.00) with value 79.00
# ...
# Number of photons after filtering: 137
# Number of photons after filtering only: 137 of 3614648 Ratio: 3.79013392175393e-05
# Number of photons in event 0: 343991
# Bright pixel location in cm: (-435.00, -645.00) with value 109.00
# Number of photons in event after optics only 0: 1866 of 343991 Ratio: 0.005424560526292839
# Number of photons: 1866
# Number of photons after filtering: 4
# Number of photons after filtering only: 4 of 343991 Ratio: 1.1628211203200084e-05
# Number of photons in event 0: 34565
# Bright pixel location in cm: (75.00, 45.00) with value 151.00
# Number of photons in event after optics only 0: 116 of 34565 Ratio: 0.0033559959496600607
# Number of photons: 116
# Number of photons after filtering: 0
# Number of photons after filtering only: 0 of 34565 Ratio: 0.0
# No photons found in the data.
# Number of photons in event 0: 14081
# Bright pixel location in cm: (-405.00, -645.00) with value 92.00
# Number of photons in event after optics only 0: 596 of 14081 Ratio: 0.04232653930828777
# Number of photons: 596
# Number of photons after filtering: 0
# Number of photons after filtering only: 0 of 14081 Ratio: 0.0
# No photons found in the data.
# Number of photons in event 0: 4047445
# Bright pixel location in cm: (-405.00, -675.00) with value 8416.00
# Number of photons in event after optics only 0: 132264 of 4047445 Ratio: 0.032678393406210586
# Number of photons: 132264
# Number of photons after filtering: 249
# Number of photons after filtering only: 249 of 4047445 Ratio: 6.152029243139807e-05
# Number of photons in event 0: 201982
# Bright pixel location in cm: (-405.00, -645.00) with value 880.00
# Number of photons in event after optics only 0: 7998 of 201982 Ratio: 0.03959758790387262
# Number of photons: 7998
# Number of photons after filtering: 14
# Number of photons after filtering only: 14 of 201982 Ratio: 6.931310710855422e-05
# Number of photons in event 0: 278219
# Bright pixel location in cm: (-195.00, -315.00) with value 255.00
# Number of photons in event after optics only 0: 1671 of 278219 Ratio: 0.006006059974336763
# Number of photons: 1671
# Number of photons after filtering: 9
# Number of photons after filtering only: 9 of 278219 Ratio: 3.234861745603284e-05
# Number of photons in event 0: 1130674
# Bright pixel location in cm: (-495.00, -495.00) with value 916.00
# Number of photons in event after optics only 0: 16162 of 1130674 Ratio: 0.014294128988550193
# Number of photons: 16162
# Number of photons after filtering: 25
# Number of photons after filtering only: 25 of 1130674 Ratio: 2.2110705649904394e-05
# Number of photons in event 0: 343798
# Bright pixel location in cm: (-405.00, -645.00) with value 1681.00
# Number of photons in event after optics only 0: 18493 of 343798 Ratio: 0.053790307098936
# Number of photons: 18493
# Number of photons after filtering: 34
# Number of photons after filtering only: 34 of 343798 Ratio: 9.889528153159705e-05
# Number of photons in event 0: 335488
# Bright pixel location in cm: (-465.00, -615.00) with value 390.00
# Number of photons in event after optics only 0: 5499 of 335488 Ratio: 0.016391048264021366
# Number of photons: 5499
# Number of photons after filtering: 12
# Number of photons after filtering only: 12 of 335488 Ratio: 3.576879053796261e-05
# Number of photons in event 0: 166997
# Bright pixel location in cm: (-405.00, -675.00) with value 115.00
# Number of photons in event after optics only 0: 1241 of 166997 Ratio: 0.007431271220441086
# Number of photons: 1241
# Number of photons after filtering: 2
# Number of photons after filtering only: 2 of 166997 Ratio: 1.1976263046641557e-05
# Number of photons in event 0: 663379
# Bright pixel location in cm: (-495.00, -645.00) with value 1080.00
# Number of photons in event after optics only 0: 19287 of 663379 Ratio: 0.029073877828511303
# Number of photons: 19287
# Number of photons after filtering: 39
# Number of photons after filtering only: 39 of 663379 Ratio: 5.878992250282267e-05
# Number of photons in event 0: 293222
# Bright pixel location in cm: (-405.00, -675.00) with value 370.00
# Number of photons in event after optics only 0: 5616 of 293222 Ratio: 0.019152723874743368
# Number of photons: 5616
# Number of photons after filtering: 7
# Number of photons after filtering only: 7 of 293222 Ratio: 2.3872697137322575e-05
# Number of photons in event 0: 20258
# Bright pixel location in cm: (-75.00, -1155.00) with value 133.00
# Number of photons in event after optics only 0: 218 of 20258 Ratio: 0.010761180768091618
# Number of photons: 218
# Number of photons after filtering: 0
# Number of photons after filtering only: 0 of 20258 Ratio: 0.0
# No photons found in the data.
# Number of photons in event 0: 2565778
# Bright pixel location in cm: (-405.00, -645.00) with value 1473.00
# Number of photons in event after optics only 0: 27725 of 2565778 Ratio: 0.010805689346467232
# Number of photons: 27725
# Number of photons after filtering: 54
# Number of photons after filtering only: 54 of 2565778 Ratio: 2.104624796065755e-05
# Number of photons in event 0: 412649
# Bright pixel location in cm: (-435.00, -645.00) with value 945.00
# Number of photons in event after optics only 0: 12907 of 412649 Ratio: 0.031278398832906416
# Number of photons: 12907
# Number of photons after filtering: 21
# Number of photons after filtering only: 21 of 412649 Ratio: 5.089070856829897e-05
# Number of photons in event 0: 70409
# Bright pixel location in cm: (-405.00, -645.00) with value 272.00
# Number of photons in event after optics only 0: 2613 of 70409 Ratio: 0.03711173287505859
# Number of photons: 2613
# Number of photons after filtering: 7
# Number of photons after filtering only: 7 of 70409 Ratio: 9.941910835262538e-05
# Number of photons in event 0: 125345
# Bright pixel location in cm: (-75.00, 45.00) with value 230.00
# Number of photons in event after optics only 0: 613 of 125345 Ratio: 0.004890502213889664
# Number of photons: 613
# Number of photons after filtering: 1
# Number of photons after filtering only: 1 of 125345 Ratio: 7.977980773066336e-06
# No histograms created. Check your data and filter conditions.
# Number of photons in event 0: 1488254
# Bright pixel location in cm: (-405.00, -675.00) with value 4611.00
# Number of photons in event after optics only 0: 66267 of 1488254 Ratio: 0.04452667353825355
# Number of photons: 66267
# Number of photons after filtering: 113
# Number of photons after filtering only: 113 of 1488254 Ratio: 7.592789940426835e-05
# Number of photons in event 0: 407893
# Bright pixel location in cm: (-315.00, -705.00) with value 444.00
# Number of photons in event after optics only 0: 5907 of 407893 Ratio: 0.014481739083534163
# Number of photons: 5907
# Number of photons after filtering: 14
# Number of photons after filtering only: 14 of 407893 Ratio: 3.432272679354635e-05
# Number of photons in event 0: 29664
# Bright pixel location in cm: (-405.00, -675.00) with value 94.00
# Number of photons in event after optics only 0: 681 of 29664 Ratio: 0.022957119741100325
# Number of photons: 681
# Number of photons after filtering: 4
# Number of photons after filtering only: 4 of 29664 Ratio: 0.00013484358144552318
# Number of photons in event 0: 791882
# Bright pixel location in cm: (-435.00, -675.00) with value 2317.00
# Number of photons in event after optics only 0: 30904 of 791882 Ratio: 0.039026016502458696
# Number of photons: 30904
# Number of photons after filtering: 66
# Number of photons after filtering only: 66 of 791882 Ratio: 8.33457510083573e-05
# Number of photons in event 0: 268739
# Bright pixel location in cm: (-405.00, -525.00) with value 381.00
# Number of photons in event after optics only 0: 5663 of 268739 Ratio: 0.02107249040890976
# Number of photons: 5663
# Number of photons after filtering: 14
# Number of photons after filtering only: 14 of 268739 Ratio: 5.209515552264465e-05
# Number of photons in event 0: 46357
# Bright pixel location in cm: (-405.00, -645.00) with value 87.00
# Number of photons in event after optics only 0: 800 of 46357 Ratio: 0.01725737213365835
# Number of photons: 800
# Number of photons after filtering: 2
# Number of photons after filtering only: 2 of 46357 Ratio: 4.314343033414587e-05
# Number of photons in event 0: 2135195
# Bright pixel location in cm: (-405.00, -465.00) with value 804.00
# Number of photons in event after optics only 0: 14663 of 2135195 Ratio: 0.0068672884677980234
# Number of photons: 14663
# Number of photons after filtering: 27
# Number of photons after filtering only: 27 of 2135195 Ratio: 1.2645215074033051e-05
# Number of photons in event 0: 253047
# Bright pixel location in cm: (-825.00, -345.00) with value 206.00
# Number of photons in event after optics only 0: 1845 of 253047 Ratio: 0.007291135638833893
# Number of photons: 1845
# Number of photons after filtering: 2
# Number of photons after filtering only: 2 of 253047 Ratio: 7.903670069196632e-06
# Number of photons in event 0: 17662
# Bright pixel location in cm: (-405.00, -645.00) with value 96.00
# Number of photons in event after optics only 0: 623 of 17662 Ratio: 0.03527346846336768
# Number of photons: 623
# Number of photons after filtering: 2
# Number of photons after filtering only: 2 of 17662 Ratio: 0.00011323745895142112
# Number of photons in event 0: 29720
# Bright pixel location in cm: (-405.00, -645.00) with value 103.00
# Number of photons in event after optics only 0: 654 of 29720 Ratio: 0.022005383580080754
# Number of photons: 654
# Number of photons after filtering: 1
# Number of photons after filtering only: 1 of 29720 Ratio: 3.364737550471063e-05
# No histograms created. Check your data and filter conditions.
# Number of photons in event 0: 1009133
# Bright pixel location in cm: (-405.00, -675.00) with value 3282.00
# Number of photons in event after optics only 0: 38695 of 1009133 Ratio: 0.03834479696927957
# Number of photons: 38695
# Number of photons after filtering: 81
# Number of photons after filtering only: 81 of 1009133 Ratio: 8.02669221995515e-05
# Number of photons in event 0: 40927
# Bright pixel location in cm: (-405.00, -675.00) with value 99.00
# Number of photons in event after optics only 0: 628 of 40927 Ratio: 0.015344393676546046
# Number of photons: 628
# Number of photons after filtering: 1
# Number of photons after filtering only: 1 of 40927 Ratio: 2.4433747892589244e-05
# No histograms created. Check your data and filter conditions.
# Number of photons in event 0: 35274
# Bright pixel location in cm: (-405.00, -645.00) with value 91.00
# Number of photons in event after optics only 0: 716 of 35274 Ratio: 0.02029823666156376
# Number of photons: 716
# Number of photons after filtering: 0
# Number of photons after filtering only: 0 of 35274 Ratio: 0.0
# No photons found in the data.
# Number of photons in event 0: 273002
# Bright pixel location in cm: (-375.00, -675.00) with value 255.00
# Number of photons in event after optics only 0: 4089 of 273002 Ratio: 0.014977912249727108
# Number of photons: 4089
# Number of photons after filtering: 8
# Number of photons after filtering only: 8 of 273002 Ratio: 2.930381462406869e-05
# Number of photons in event 0: 18679
# Bright pixel location in cm: (-405.00, -645.00) with value 94.00
# Number of photons in event after optics only 0: 616 of 18679 Ratio: 0.03297821082499063
# Number of photons: 616
# Number of photons after filtering: 2
# Number of photons after filtering only: 2 of 18679 Ratio: 0.0001070721130681514
# Number of photons in event 0: 36522
# Bright pixel location in cm: (-405.00, -675.00) with value 103.00
# Number of photons in event after optics only 0: 673 of 36522 Ratio: 0.018427249329171457
# Number of photons: 673
# Number of photons after filtering: 0
# Number of photons after filtering only: 0 of 36522 Ratio: 0.0
# No photons found in the data.
# Number of photons in event 0: 1342303
# Bright pixel location in cm: (-555.00, -735.00) with value 431.00
# Number of photons in event after optics only 0: 7433 of 1342303 Ratio: 0.005537497867471056
# Number of photons: 7433
# Number of photons after filtering: 15
# Number of photons after filtering only: 15 of 1342303 Ratio: 1.1174824164141777e-05
# Number of photons in event 0: 962732
# Bright pixel location in cm: (-405.00, -675.00) with value 2652.00
# Number of photons in event after optics only 0: 34795 of 962732 Ratio: 0.036141937735527645
# Number of photons: 34795
# Number of photons after filtering: 66
# Number of photons after filtering only: 66 of 962732 Ratio: 6.855490416855366e-05
# Number of photons in event 0: 15772
# Bright pixel location in cm: (-405.00, -645.00) with value 106.00
# Number of photons in event after optics only 0: 611 of 15772 Ratio: 0.038739538422520925
# Number of photons: 611
# Number of photons after filtering: 2
# Number of photons after filtering only: 2 of 15772 Ratio: 0.000126806999746386
# Number of photons in event 0: 32330
# Bright pixel location in cm: (-405.00, -645.00) with value 94.00
# Number of photons in event after optics only 0: 686 of 32330 Ratio: 0.021218682338385402
# Number of photons: 686
# Number of photons after filtering: 1
# Number of photons after filtering only: 1 of 32330 Ratio: 3.093102381688834e-05
# No histograms created. Check your data and filter conditions.
# Number of photons in event 0: 2671602
# Bright pixel location in cm: (-405.00, -615.00) with value 2681.00
# Number of photons in event after optics only 0: 53246 of 2671602 Ratio: 0.019930363879050846
# Number of photons: 53246
# Number of photons after filtering: 104
# Number of photons after filtering only: 104 of 2671602 Ratio: 3.892795408896984e-05
# Number of photons in event 0: 55322
# Bright pixel location in cm: (-405.00, -675.00) with value 114.00
# Number of photons in event after optics only 0: 727 of 55322 Ratio: 0.013141245797331984
# Number of photons: 727
# Number of photons after filtering: 2
# Number of photons after filtering only: 2 of 55322 Ratio: 3.615198293626405e-05
# Number of photons in event 0: 46810
# Bright pixel location in cm: (-405.00, -675.00) with value 91.00
# Number of photons in event after optics only 0: 719 of 46810 Ratio: 0.015359965819269386
# Number of photons: 719
# Number of photons after filtering: 2
# Number of photons after filtering only: 2 of 46810 Ratio: 4.272591326639607e-05
# Number of photons in event 0: 1254223
# Bright pixel location in cm: (-435.00, -675.00) with value 2785.00
# Number of photons in event after optics only 0: 44390 of 1254223 Ratio: 0.03539243021376581
# Number of photons: 44390
# Number of photons after filtering: 86
# Number of photons after filtering only: 86 of 1254223 Ratio: 6.856834869078306e-05
# Number of photons in event 0: 15169
# Bright pixel location in cm: (-405.00, -675.00) with value 103.00
# Number of photons in event after optics only 0: 592 of 15169 Ratio: 0.03902696288483091
# Number of photons: 592
# Number of photons after filtering: 1
# Number of photons after filtering only: 1 of 15169 Ratio: 6.592392379194409e-05
# No histograms created. Check your data and filter conditions.
# Number of photons in event 0: 91335
# Bright pixel location in cm: (-435.00, -495.00) with value 174.00
# Number of photons in event after optics only 0: 1804 of 91335 Ratio: 0.019751464389335963
# Number of photons: 1804
# Number of photons after filtering: 1
# Number of photons after filtering only: 1 of 91335 Ratio: 1.094870531559643e-05
# No histograms created. Check your data and filter conditions.
# Number of photons in event 0: 936562
# Bright pixel location in cm: (-195.00, -345.00) with value 287.00
# Number of photons in event after optics only 0: 3534 of 936562 Ratio: 0.003773375387854728
# Number of photons: 3534
# Number of photons after filtering: 9
# Number of photons after filtering only: 9 of 936562 Ratio: 9.609614739867728e-06
# Number of photons in event 0: 68166
# Bright pixel location in cm: (-405.00, -675.00) with value 101.00
# Number of photons in event after optics only 0: 791 of 68166 Ratio: 0.011604025467241734
# Number of photons: 791
# Number of photons after filtering: 2
# Number of photons after filtering only: 2 of 68166 Ratio: 2.9340140245870375e-05
# Number of photons in event 0: 43927
# Bright pixel location in cm: (-645.00, -765.00) with value 210.00
# Number of photons in event after optics only 0: 2149 of 43927 Ratio: 0.04892207526122886
# Number of photons: 2149
# Number of photons after filtering: 5
# Number of photons after filtering only: 5 of 43927 Ratio: 0.00011382521000751247

# %%
import matplotlib.pyplot as plt
colors = ['b', 'y', 'r', 'c', 'g', 'black', 'm']  # Define colors for each zenith angle
Count =[[calculate_pe_statistics(i) for i in Num_triggered_events[j]]  for j in range(len(zenith_angles))] # Example to test median calculation
Count = np.array(Count)
plt.figure(figsize=(10, 6))
for i, height in enumerate(Pro_Height_float[0]):
    plt.plot(zenith_angles, Count[:,i], "--o", color=colors[i], label=f'Production Height: {height} km')
plt.xlabel('Zenith Angle (degrees)')
plt.ylabel('Poisson Detection Efficiency')
plt.legend()
plt.grid()
#plt.yscale('log')  # Use logarithmic scale for better visibility
plt.title('Poisson Detection Efficiency vs Zenith Angle for Different Production Heights of 1 PeV Muons')
plt.show()

# %%
#I want to have the error bar representing thr min and max values
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.plot(zenith, H[:, 0], marker='o', label='Median Histogram Counts')
plt.plot(zenith, H[:, 1], marker='o', label='Max Histogram Counts')
plt.plot(zenith, H[:, 2], marker='o', label='Mean Histogram Counts')
plt.xlabel('Zenith Angle (degrees)')
plt.ylabel('Values')
plt.legend()
plt.grid()
plt.yscale('symlog')  # Use logarithmic scale for better visibility
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(zenith, Z[:, 0], marker='o', label='Median Zem')
#plt.plot(zenith, Z[:, 1], marker='o', label='Max Zem')
plt.plot(zenith, Z[:, 2], marker='o', label='Mean Zem')
plt.xlabel('Zenith Angle (degrees)')
plt.ylabel('Zem Values')  
#plt.yscale('log')  
plt.grid()
plt.legend()
plt.title('Zem Values vs Zenith Angle')
plt.show()
# Out:
# Exception ignored in: <function EventIOFile.__del__ at 0x14d54be13a60>
# Traceback (most recent call last):
#   File "/uufs/chpc.utah.edu/common/home/u1520754/miniconda3/envs/jupyter_env/lib/python3.9/site-packages/eventio/base.py", line 157, in __del__
#     self.close()
#   File "/uufs/chpc.utah.edu/common/home/u1520754/miniconda3/envs/jupyter_env/lib/python3.9/site-packages/eventio/base.py", line 154, in close
#     self._filehandle.close()
# AttributeError: 'IACTFile' object has no attribute '_filehandle'

# %%
plt.figure(figsize=(10, 6))
plt.plot(zenith, Theta[:, 0], marker='o', label='Median Theta')
#plt.plot(zenith, Theta[:, 1], marker='o', label='Max Theta')
plt.plot(zenith, Theta[:, 2], marker='o', label='Mean Theta')
plt.xlabel('Zenith Angle (degrees)')
plt.ylabel('Theta Values')  
#plt.yscale('log')  
plt.grid()
plt.legend()
plt.title('Zem Values vs Zenith Angle')
plt.show()
